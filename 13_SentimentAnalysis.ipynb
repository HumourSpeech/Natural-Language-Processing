# %% [markdown]
# ## Best Practices
#
# 1. Preprocessing And Cleaning(feature engineering)
# 2. Train Test Split
# 3. Bow, Tf-Idf, Word2Vec
# 4. Train ML algorithms

# %%
# Load the dataset
import pandas as pd
data = pd.read_csv('datasets/all_kindle_review.csv')

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0        asin  helpful  rating  \
# 0             0       11539  B0033UV8HI  [8, 10]       3
# 1             1        5957  B002HJV4DE   [1, 1]       5
# 2             2        9146  B002ZG96I4   [0, 0]       3
# 3             3        7038  B002QHWOEU   [1, 3]       3
# 4             4        1776  B001A06VJ8   [0, 1]       4
#
#                                           reviewText   reviewTime  \
# 0  Jace Rankin may be short, but he's nothing to ...   09 2, 2010
# 1  Great short read.  I didn't want to put it dow...   10 8, 2013
# 2  I'll start by saying this is the first of four...  04 11, 2014
# 3  Aggie is Angela Lansbury who carries pocketboo...   07 5, 2014
# 4  I did not expect this type of book to be in li...  12 31, 2012
#
#        reviewerID  reviewerName                   summary  unixReviewTime
# 0  A3HHXRELK8BHQG        Ridley  Entertaining But Average      1283385600
# 1  A2RGNZ0TRF578I  Holly Butler   Terrific menage scenes!      1381190400
# 2  A3S0H2HV6U1I7F       Merissa          Snapdragon Alley      1397174400
# 3   AC4OQW3GZ919J    Cleargrace    very light murder cozy      1404518400
# 4  A3C9V987IQHOQD      Rjostler                      Book      1356912000

# %%
df = data[['reviewText','rating']]
df.head()
# Out:
#                                           reviewText  rating
# 0  Jace Rankin may be short, but he's nothing to ...       3
# 1  Great short read.  I didn't want to put it dow...       5
# 2  I'll start by saying this is the first of four...       3
# 3  Aggie is Angela Lansbury who carries pocketboo...       3
# 4  I did not expect this type of book to be in li...       4

# %%
df.shape
# Out:
# (12000, 2)

# %%
## missing values
df.isnull().sum()
# Out:
# reviewText    0
# rating        0
# dtype: int64

# %%
df['rating'].unique()
# Out:
# array([3, 5, 4, 2, 1], dtype=int64)

# %%
df['rating'].value_counts()
# Out:
# rating
# 5    3000
# 4    3000
# 3    2000
# 2    2000
# 1    2000
# Name: count, dtype: int64

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Preprocessing and Cleaning

# %%
df = df.copy()

# %%
## positive review is 1 and negative review is 0
df['rating'] = df['rating'].apply(lambda x:0 if x<3 else 1)

# %%
df['rating'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
## 1. Lower All the Cases
df['reviewText'] = df['reviewText'].str.lower()

# %%
df.head()
# Out:
#                                           reviewText  rating
# 0  jace rankin may be short, but he's nothing to ...       1
# 1  great short read.  i didn't want to put it dow...       1
# 2  i'll start by saying this is the first of four...       1
# 3  aggie is angela lansbury who carries pocketboo...       1
# 4  i did not expect this type of book to be in li...       1

# %%
import re
import nltk
from nltk.corpus import stopwords

# %%
from bs4 import BeautifulSoup

# %%
## Removing Special Characters
df['reviewText'] = df['reviewText'].apply(lambda x:re.sub('[^a-z A-Z 0-9-]+','',x))

## Removing the stopwords
# df['reviewText'] = df['reviewText'].apply(lambda x:" ".join([y for y in x.split() if y not in stopwords.words('english')]))
stop_words = set(stopwords.words('english'))
df['reviewText'] = df['reviewText'].apply(lambda x: " ".join([word for word in x.split() if word not in stop_words]))

## Removing url
df['reviewText'] = df['reviewText'].apply(lambda x: re.sub(r'(http|https|ftp|ssh)://([\w_-]+(?:(?:\.[\w_-]+)+))([\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?','', str(x)))

## Removing  html tags
df['reviewText'] = df['reviewText'].apply(lambda x: BeautifulSoup(x, 'lxml').get_text())

## Removing any additional spaces
df['reviewText'] = df['reviewText'].apply(lambda x: " ".join(x.split()))

# %%
df.head()
# Out:
#                                           reviewText  rating
# 0  jace rankin may short hes nothing mess man hau...       1
# 1  great short read didnt want put read one sitti...       1
# 2  ill start saying first four books wasnt expect...       1
# 3  aggie angela lansbury carries pocketbooks inst...       1
# 4  expect type book library pleased find price right       1

# %%
## Lemmatizer 
from  nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

# %%
df['reviewText'] = df['reviewText'].apply(lambda x:lemmatize_words(x))

# %%
df.head()
# Out:
#                                           reviewText  rating
# 0  jace rankin may short he nothing mess man haul...       1
# 1  great short read didnt want put read one sitti...       1
# 2  ill start saying first four book wasnt expecti...       1
# 3  aggie angela lansbury carry pocketbook instead...       1
# 4  expect type book library pleased find price right       1

# %%
## Train Test split
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(df['reviewText'],df['rating'],test_size=0.20)

# %%
X_train.shape
# Out:
# (9600,)

# %% [markdown]
# ## Implementing Word2Vec

# %%
import gensim

# %%
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
import numpy as np

# %%
# Tokenize the reviews
X_train_tokens = [word_tokenize(review.lower()) for review in X_train]
X_test_tokens = [word_tokenize(review.lower()) for review in X_test]

# %%
X_train_tokens
# Out:
# [['iam',
#   'literary',
#   'critic',
#   'tough',
#   'time',
#   'spelling',
#   'correctly',
#   'said',
#   'give',
#   'author',
#   'one',
#   'star',
#   'writing',
#   'book',
#   'seriesiam',
#   'huge',
#   'fan',
#   'avid',
#   'reader',
#   'military',
#   'space',
#   'opera',
#   'strong',
#   'heroine',
#   'gave',
#   'work',
#   'try',
#   'hooked',
#   'enough',
#   'buy',
#   'last',
#   'novel',
#   'see',
#   'ended',
#   'hence',
#   'second',
#   'star',
#   'bashing',
#   'work',
#   'iam',
#   'prude',
#   'religious',
#   'do-gooder',
#   'sexual',
#   'relation',
#   'deleted',
#   'wouldnt',
#   'much',
#   'story',
#   'left',
#   'whats',
#   'left',
#   'believeable',
#   'least',
#   'any-one',
#   'military',
#   'experience',
#   'common',
#   'sensethe',
#   'fact',
#   'series',
#   'huge',
#   'potential',
#   'science',
#   'isnt',
#   'bad',
#   'main',
#   'character',
#   'loveable',
#   'many',
#   'battle',
#   'scene',
#   'well',
#   'described',
#   'five',
#   'star',
#   'work'],
#  ['enjoyable',
#   'story',
#   'start',
#   'twist',
#   'plot',
#   'change',
#   'constantly',
#   'trying',
#   'figure',
#   'villain',
#   'good',
#   'love',
#   'story'],
#  ['im',
#   'sorry',
#   'dont',
#   'like',
#   'short',
#   'story',
#   'collection',
#   'mascarade',
#   'novel',
#   'little',
#   'character',
#   'developement',
#   'story',
#   'plot',
#   'save',
#   'money',
#   'something',
#   'take',
#   'longer',
#   '15',
#   'minute',
#   'read'],
#  ['ok',
#   'read',
#   'predictable',
#   'little',
#   'short',
#   'side',
#   'like',
#   'long',
#   'book',
#   'give',
#   'hour',
#   'escape'],
#  ['plotstoryline',
#   '4',
#   '12',
#   'starsafter',
#   'short',
#   'prologue',
#   'book',
#   'opened',
#   'scene',
#   'family',
#   'life',
#   'near',
#   'christmas',
#   'little',
#   'introduction',
#   'father',
#   'jump',
#   'tale',
#   'saint',
#   'nick',
#   'origin',
#   'legend',
#   'santa',
#   'claussaint',
#   'nick',
#   'story',
#   'interesting',
#   'mix',
#   'fantasy',
#   'history',
#   'life',
#   'seemed',
#   'mirror',
#   'much',
#   'jesus',
#   'christ',
#   'christian',
#   'forewarned',
#   'sort',
#   'thing',
#   'disturbs',
#   'obviously',
#   'plenty',
#   'research',
#   'went',
#   'writing',
#   'novel',
#   'author',
#   'applauded',
#   'wasnt',
#   'really',
#   'able',
#   'get',
#   'santa',
#   'claus',
#   'healer',
#   'thing',
#   'make',
#   'interesting',
#   'read',
#   'wondering',
#   'yes',
#   'explanation',
#   'elf',
#   'reindeer',
#   'tooone',
#   'drawback',
#   'found',
#   'difficult',
#   'imagine',
#   'man',
#   'telling',
#   'gruesome',
#   'part',
#   'story',
#   'child',
#   'initially',
#   'child',
#   'listening',
#   'story',
#   'young',
#   'girl',
#   'preschool',
#   'age',
#   'think',
#   'audience',
#   'later',
#   'switched',
#   'prepubescent',
#   'boy',
#   'however',
#   'still',
#   'felt',
#   'part',
#   'graphic',
#   'even',
#   'age',
#   'groupthe',
#   'story',
#   'drag',
#   'little',
#   'middle',
#   'really',
#   'enjoyed',
#   'interval',
#   'modern',
#   'day',
#   'family',
#   'christmas',
#   'story',
#   'father',
#   'christmas',
#   'tree',
#   'laughing',
#   'loud',
#   'little',
#   'interval',
#   'sparse',
#   'might',
#   'spiced',
#   'storyline',
#   'somewhat',
#   'least',
#   'little',
#   'humor',
#   'interspersed',
#   'would',
#   'given',
#   'book',
#   'upbeat',
#   'feelingthis',
#   'novel',
#   'would',
#   'ever',
#   'become',
#   'part',
#   'christmas',
#   'tradition',
#   'way',
#   'depressing',
#   'even',
#   'though',
#   'oddly',
#   'time',
#   'offered',
#   'wonderful',
#   'explanation',
#   'tradition',
#   'christmas',
#   'involve',
#   'santa',
#   'clauscharacters',
#   '4',
#   '12',
#   'starsalthough',
#   'story',
#   'saint',
#   'nick',
#   'well',
#   'developed',
#   'insofar',
#   'reader',
#   'privvy',
#   'enough',
#   'thought',
#   'wanted',
#   'know',
#   'really',
#   'thinking',
#   'found',
#   'able',
#   'heal',
#   'seemed',
#   'take',
#   'granted',
#   'understand',
#   'awhile',
#   'first',
#   'time',
#   'exciting',
#   'induce',
#   'kind',
#   'emotion',
#   'think',
#   'mirroring',
#   'life',
#   'christ',
#   'author',
#   'presented',
#   'story',
#   'much',
#   'way',
#   'bystander',
#   'would',
#   'far',
#   'interesting',
#   'since',
#   'fictional',
#   'given',
#   'insightwriting',
#   'style',
#   '4',
#   '12',
#   'starsthe',
#   'writing',
#   'style',
#   'excellent',
#   'many',
#   'portion',
#   'story',
#   'even',
#   'though',
#   'felt',
#   'novel',
#   'lagged',
#   'area',
#   'others',
#   'writing',
#   'scene',
#   'felt',
#   'rushed',
#   'point',
#   'read',
#   'section',
#   'twice',
#   'catch',
#   'everything',
#   'description',
#   'vivid',
#   'picturesque',
#   'dialogue',
#   'pretty',
#   'good',
#   'felt',
#   'better',
#   'job',
#   'could',
#   'done',
#   'accent',
#   'vocabulary',
#   'give',
#   'feel',
#   'time',
#   'period'],
#  ['instead',
#   'story',
#   'interspersed',
#   'sex',
#   'scene',
#   'sex',
#   'scene',
#   'interrupted',
#   'occasional',
#   'plot',
#   'scene',
#   'promising',
#   'plot',
#   'unfortuately',
#   'wasnt',
#   'developed',
#   'enough',
#   'decently',
#   'edited',
#   'free'],
#  ['really',
#   'like',
#   'learn',
#   'woman',
#   'managed',
#   'n',
#   'past',
#   'good',
#   'read',
#   'positive',
#   'outlook',
#   'someone',
#   '11',
#   'child',
#   'born',
#   'home-'],
#  ['joseph',
#   'boyden',
#   'seems',
#   'incapable',
#   'telling',
#   'narrative',
#   'story',
#   'start',
#   'finish',
#   'rather',
#   'jump',
#   'around',
#   'present',
#   'various',
#   'point',
#   'past',
#   'moving',
#   'point',
#   'view',
#   'person',
#   'person',
#   'make',
#   'challenging',
#   'reading',
#   'youre',
#   'challenge',
#   'tell',
#   'cracking',
#   'good',
#   'story',
#   'working',
#   'book',
#   'half',
#   'decade',
#   'finally',
#   'clicked',
#   'last',
#   'night',
#   'set',
#   'moosonee',
#   'various',
#   'point',
#   'south',
#   'filled',
#   'usual',
#   'reference',
#   'alcohol',
#   'abuse',
#   'residential',
#   'school',
#   'living',
#   'land',
#   'hadnt',
#   'guessed',
#   'subject',
#   'anishinabe',
#   'attempt',
#   'made',
#   'varnish',
#   'hardship',
#   'pride',
#   'challenge',
#   'life',
#   'profanity',
#   'somehow',
#   'doesnt',
#   'seem',
#   'jarring',
#   'context',
#   'ware'],
#  ['nice',
#   'story',
#   'wallflower',
#   'getting',
#   'sexy',
#   'guy',
#   'quick',
#   'read',
#   'wish',
#   'charecters',
#   'fleshed',
#   'little',
#   'story',
#   'little',
#   'depth'],
#  ['normally',
#   'dont',
#   'issue',
#   'naive',
#   'love',
#   'story',
#   'two',
#   'vacuous',
#   'common',
#   'sense',
#   'usually',
#   'like',
#   'ea',
#   'story',
#   'one'],
#  ['freebie',
#   'kindle',
#   'always',
#   'hate',
#   'complain',
#   'dis',
#   'anything',
#   'free',
#   'however',
#   'guess',
#   'expected',
#   'quote',
#   'modern',
#   'many',
#   'quote',
#   'seemed',
#   'old',
#   'archaic',
#   'partial',
#   'nature',
#   'didnt',
#   'really',
#   'seem',
#   'bearing',
#   'anything',
#   'particular',
#   'many',
#   'great',
#   'quote',
#   'shakespeare',
#   'famous',
#   'author',
#   'wasnt',
#   'looking',
#   'quote',
#   'one',
#   'thing',
#   'could',
#   'made',
#   'better',
#   'perhaps',
#   'would',
#   'guide',
#   'help',
#   'findselect',
#   'particular',
#   'quote',
#   'would',
#   'apropo',
#   'something',
#   'searching',
#   'pertain',
#   'particular',
#   'situation',
#   'let',
#   'say',
#   'example',
#   'wanted',
#   'write',
#   'wedding',
#   'vow',
#   'need',
#   'inspiration',
#   'lonely',
#   'need',
#   'support',
#   'guide',
#   'front',
#   'book',
#   'lead',
#   'particular',
#   'referencequote',
#   'would',
#   'nice',
#   'believe',
#   'still',
#   'worthwhile',
#   'looking',
#   'book',
#   'called',
#   'familiar',
#   'quotation'],
#  ['enjoy',
#   'reading',
#   'menage',
#   'party',
#   'involved',
#   'deeply',
#   'love',
#   'usually',
#   'known',
#   'year',
#   'hero',
#   'looking',
#   'exclusive',
#   'committed',
#   'relationship',
#   'series',
#   'rutting',
#   'group',
#   'people',
#   'cookie',
#   'cutter',
#   'plot',
#   'series-hero',
#   'lustlove',
#   'heroine',
#   'year',
#   'pushing',
#   'away',
#   'yearscheck-he',
#   'decides',
#   'cant',
#   'wait',
#   'anymore',
#   'persuescheck-he',
#   'get',
#   'help',
#   'relative',
#   'best',
#   'friend',
#   'betrayal',
#   'sortcheck-hero',
#   'best',
#   'friend',
#   'relative',
#   'know',
#   'heroine',
#   'denying',
#   'nature',
#   'know',
#   'best',
#   'hercheck-hero',
#   'brings',
#   'friend',
#   'heroine',
#   'never',
#   'seen',
#   'met',
#   'menage',
#   'sexcheck-heroes',
#   'friend',
#   'doesnt',
#   'even',
#   'show',
#   'book',
#   'deed',
#   'going',
#   'donecheck-heroes',
#   'friend',
#   'get',
#   'easy',
#   'free',
#   'lay',
#   'woman',
#   'he',
#   'doesnt',
#   'know',
#   'doesnt',
#   'even',
#   'wine',
#   'dine',
#   'hercheck-his',
#   'friend',
#   'deed',
#   'take',
#   'immediately',
#   'aftercheckthat',
#   'say',
#   'dont',
#   'feel',
#   'great',
#   'love',
#   'hh',
#   'basically',
#   'bunch',
#   'people',
#   'swapping',
#   'didnt',
#   'even',
#   'get',
#   'impression',
#   'real',
#   'feeling',
#   'going',
#   'person',
#   'betrays',
#   'heroine',
#   'heroine',
#   'sad',
#   'kind',
#   'event',
#   'pathetic',
#   'really',
#   'hero',
#   'definetly',
#   'jealous',
#   'possessive',
#   'type',
#   'looking',
#   'avoid',
#   'seriessave',
#   'money',
#   'much',
#   'better',
#   'menage',
#   'series'],
#  ['far',
#   'fairy',
#   'tale',
#   'big',
#   'surprise',
#   'mostly',
#   'typical',
#   'fairy',
#   'tale',
#   'fare',
#   'bad',
#   'thing',
#   'resembled',
#   'european',
#   'fairy',
#   'tale',
#   'much',
#   'form',
#   'function',
#   'wonder',
#   'translation',
#   'indeed',
#   'indian',
#   'fairy',
#   'tale',
#   'similar',
#   'european',
#   'one',
#   'enjoy',
#   'european',
#   'style',
#   'mythology',
#   'probably',
#   'like',
#   'short',
#   'set',
#   'tale'],
#  ['like',
#   'western',
#   'youll',
#   'love',
#   'book',
#   'great',
#   'story',
#   'great',
#   'character',
#   'book',
#   'well',
#   'worth',
#   'reading',
#   'go',
#   'ahead',
#   'try'],
#  ['50',
#   'year',
#   'old',
#   'dialog',
#   'hopelesly',
#   'date',
#   'childish',
#   'today',
#   'great',
#   're-read',
#   'old',
#   'pulp',
#   'sci-fi',
#   'childhood'],
#  ['greg',
#   'mckenzie',
#   'worst',
#   'enemy',
#   'greg',
#   '65',
#   'year',
#   'old',
#   'retired',
#   'intelligence',
#   'agent',
#   'da',
#   'inspector',
#   'derailed',
#   'career',
#   'several',
#   'time',
#   'blowing',
#   'lid',
#   'spouting',
#   'greg',
#   'chip',
#   'shoulder',
#   'feel',
#   'former',
#   'supervisor',
#   'co-worker',
#   'singled',
#   'retribution',
#   'he',
#   'probably',
#   'rightwhen',
#   'greg',
#   'wife',
#   'jill',
#   'take',
#   'trip',
#   'holy',
#   'land',
#   'church',
#   'group',
#   'greg',
#   'supposed',
#   'work',
#   'anger',
#   'management',
#   'skill',
#   'returning',
#   'home',
#   'end',
#   'trip',
#   'greg',
#   'feel',
#   'jill',
#   'singled',
#   'unfair',
#   'treatment',
#   'custom',
#   'airport',
#   'securitythen',
#   'jill',
#   'kidnapped',
#   'kidnapper',
#   'group',
#   'palestinian',
#   'want',
#   'scroll',
#   'gregs',
#   'possession',
#   'seems',
#   'souvenir',
#   'scroll',
#   'greg',
#   'bought',
#   'actually',
#   'real',
#   'ancient',
#   'relic',
#   'another',
#   'group',
#   'time',
#   'radical',
#   'israeli',
#   'contact',
#   'scrollbecause',
#   'past',
#   'action',
#   'greg',
#   'can',
#   'not',
#   'count',
#   'much',
#   'help',
#   'local',
#   'law',
#   'enforcement',
#   'fbi',
#   'fortunately',
#   'friend',
#   'help',
#   'gregs',
#   'investigation',
#   'lead',
#   'tangled',
#   'trail',
#   'international',
#   'intriguewhat',
#   'scroll',
#   'saywhy',
#   'two',
#   'different',
#   'political',
#   'group',
#   'want',
#   'scrolland',
#   'greg',
#   'find',
#   'way',
#   'stay',
#   'alive',
#   'rescue',
#   'jillin',
#   'novel',
#   'chester',
#   'campbell',
#   'created',
#   'unique',
#   'character',
#   'greg',
#   'mckenzie',
#   '65',
#   'year',
#   'old',
#   'retired',
#   'investigator',
#   'experience',
#   'help',
#   'identify',
#   'lead',
#   'follow',
#   'yet',
#   'flawed',
#   'hero',
#   'sometimes',
#   'anger',
#   'mouth',
#   'get',
#   'better',
#   'flaw',
#   'make',
#   'seem',
#   'real',
#   'following',
#   'made',
#   'entertaining',
#   'read'],
#  ['well',
#   'written',
#   'good',
#   'character',
#   'development',
#   'enjoyable',
#   'uber-alpha',
#   'falling',
#   'meek',
#   'weak',
#   'pack',
#   'give',
#   'new',
#   'twist',
#   'pack',
#   'mentality',
#   'story',
#   'thing',
#   'would',
#   'like',
#   'seen',
#   'development',
#   'weaker',
#   'character',
#   'end',
#   'story',
#   'prepare',
#   'upcoming',
#   'battle',
#   'show',
#   'growth',
#   'development',
#   'relationship',
#   'well',
#   'personally'],
#  ['one',
#   'classic',
#   'always',
#   'heard',
#   'seen',
#   'movie',
#   'story',
#   'worth',
#   'reading'],
#  ['really',
#   'enjoyed',
#   'second',
#   'installment',
#   'series',
#   'wish',
#   'longer',
#   'would',
#   'also',
#   'say',
#   'liked',
#   'fact',
#   'one',
#   'unlike',
#   'first',
#   'chapter',
#   'demarcation',
#   'even',
#   'though',
#   'short',
#   'chapter',
#   'demarcation',
#   'make',
#   'much',
#   'easier',
#   'see',
#   'close',
#   'end',
#   'chapter',
#   'find',
#   'stopping',
#   'place',
#   'need',
#   'although',
#   'thats',
#   'much',
#   'problem',
#   'short',
#   'novella',
#   'character',
#   'series',
#   'far',
#   'realistic',
#   'opinion',
#   'think',
#   'book',
#   'right',
#   'amount',
#   'bit',
#   'everything',
#   'except',
#   'short',
#   'wont',
#   'bore',
#   'plot',
#   'summary',
#   'know',
#   'reviewer',
#   'fond',
#   'liked',
#   'first',
#   'book',
#   'series',
#   'think',
#   'youll',
#   'like',
#   'one',
#   'give',
#   'shot',
#   'dont',
#   'think',
#   'youll',
#   'disappointed',
#   'cant',
#   'wait',
#   'read',
#   'third',
#   'final',
#   'one'],
#  ['poison',
#   'study',
#   'fire',
#   'study',
#   'magic',
#   'study-',
#   'loved',
#   'still',
#   'find',
#   'thinking',
#   'yelena',
#   'valek',
#   'adventure',
#   'never',
#   'would',
#   'thought',
#   'would',
#   'enjoy',
#   'type',
#   'book',
#   'medieval',
#   'setting',
#   'fast',
#   'fun',
#   'read',
#   'wish',
#   'romance',
#   'least',
#   'read',
#   'point',
#   'rare',
#   'rare',
#   'thing',
#   'say'],
#  ['im',
#   'much',
#   'paranormal',
#   'romance',
#   'novel',
#   'must',
#   'say',
#   'caleb',
#   'man',
#   'man',
#   'know',
#   'want',
#   'go',
#   'getting',
#   'case',
#   'want',
#   'sommer',
#   'boy',
#   'get',
#   'good',
#   'read'],
#  ['one',
#   'kept',
#   'attention',
#   'fun',
#   'read',
#   'hero',
#   '60',
#   'year',
#   'old',
#   'quite',
#   'change',
#   'interesting',
#   'easy',
#   'keep',
#   'track',
#   'except',
#   'killer',
#   'make',
#   'easier',
#   'follow',
#   'would',
#   'love',
#   'read',
#   'mr',
#   'moat',
#   'book'],
#  ['shocked',
#   'book',
#   'getting',
#   'good',
#   'review',
#   'horrible',
#   'read',
#   'like',
#   'bad',
#   'bad',
#   'porno',
#   'story',
#   'unrealistic',
#   'basically',
#   'moved',
#   'sex',
#   'scene',
#   'sex',
#   'scene',
#   'suppose',
#   'reading',
#   'sex',
#   'maybe',
#   'would',
#   'youbut',
#   'reallythe',
#   'story',
#   'little',
#   'better',
#   'one',
#   'first',
#   'book',
#   'couldnt',
#   'even',
#   'read',
#   'taking',
#   'forever',
#   'read',
#   'realized',
#   'totally',
#   'turned',
#   'never',
#   'made',
#   'time',
#   'read',
#   'plenty',
#   'erotic',
#   'type',
#   'story',
#   'believable',
#   'enjoyable',
#   'plot',
#   'linethis',
#   'one',
#   'bad',
#   'porno-esque',
#   'plot',
#   'line',
#   'put',
#   'realbut',
#   'totally',
#   'unrealistic',
#   'may',
#   'book',
#   'otherwise',
#   'way',
#   'better',
#   'choice',
#   'steamy',
#   'sex',
#   'scene'],
#  ['pass',
#   'couple',
#   'hour',
#   'dont',
#   'mind',
#   'reading',
#   'something',
#   'ok',
#   'doesnt',
#   'really',
#   'draw',
#   'one',
#   'invery',
#   'superficial',
#   'character'],
#  ['pace',
#   'short',
#   'book',
#   'fast',
#   'great',
#   'horror',
#   'thriller',
#   'big',
#   'fan',
#   'supernatural',
#   'left',
#   'wanting',
#   'something',
#   'cant',
#   'quite',
#   'place',
#   'finger',
#   'seemed',
#   'element',
#   'missing',
#   'would',
#   'totally',
#   're-read',
#   'story',
#   'entertaining',
#   'kept',
#   'interest'],
#  ['get',
#   'read',
#   'great',
#   'time',
#   'reading',
#   'couldnt',
#   'stop',
#   'reading',
#   'story',
#   'humor',
#   'irresistible',
#   'main',
#   'character',
#   'enjoyable',
#   'background',
#   'character',
#   'hot',
#   'sex',
#   'scene',
#   'like',
#   'earlier',
#   'book',
#   'series',
#   'like',
#   'short',
#   'story',
#   'long',
#   'enough',
#   'nothing',
#   'left',
#   'incomplete',
#   'dont',
#   'think',
#   'youll',
#   'get',
#   'lost',
#   'dont',
#   'read',
#   'earlier',
#   'story',
#   'series',
#   'first',
#   'story',
#   'provide',
#   'better',
#   'understanding',
#   'heroine',
#   'belle',
#   'current',
#   'predicament',
#   'get',
#   'rest',
#   'book',
#   'agree',
#   'read',
#   'order',
#   'wish',
#   'author',
#   'would',
#   'write',
#   'faster',
#   'one',
#   'addicting',
#   'series',
#   'series',
#   'reminds',
#   'lot',
#   'shelley',
#   'laurenstons',
#   'shifter',
#   'book',
#   'also',
#   'love'],
#  ['small',
#   'easy',
#   'carry',
#   'charger',
#   'car',
#   'doesnt',
#   'get',
#   'way',
#   'function',
#   'car',
#   'protects',
#   'kindle',
#   'overcharging'],
#  ['enjoyed',
#   '-',
#   'however',
#   'drag',
#   'bit',
#   'confessing',
#   'feeling',
#   'etc',
#   '-',
#   'though',
#   'took',
#   'much',
#   'time',
#   'maybe',
#   'cause',
#   'thats',
#   'way',
#   '-',
#   'tell',
#   'like',
#   'get'],
#  ['committed',
#   'reviewing',
#   'every',
#   'book',
#   'read',
#   'writer',
#   'appreciate',
#   'hard',
#   'work',
#   'go',
#   'turning',
#   'piece',
#   'work',
#   'wish',
#   'many',
#   'review',
#   'humanly',
#   'possible',
#   'novel',
#   'two',
#   'mind',
#   'liked',
#   'story',
#   'lost',
#   'track',
#   'character',
#   'came',
#   'tale',
#   'somewhat',
#   'disjointed',
#   'way',
#   'said',
#   'tale',
#   'intriguing',
#   'pleased',
#   'didnt',
#   'manage',
#   'predict',
#   'ending',
#   'also',
#   'partly',
#   'agree',
#   'one',
#   'reviewer',
#   'know',
#   'main',
#   'character',
#   'black',
#   'there',
#   'need',
#   'keep',
#   'making',
#   'reference',
#   'alluding',
#   'perhaps',
#   'special',
#   'significance',
#   'never',
#   'get',
#   'bottom',
#   'nothing',
#   'whatsoever',
#   'story',
#   'could',
#   'anyone',
#   'far',
#   'im',
#   'concerned',
#   'hope',
#   'author',
#   'sake',
#   'ive',
#   'made',
#   'fair',
#   'comment'],
#  ['parker',
#   'quinn',
#   'new',
#   'york',
#   'magazine',
#   'editor',
#   'meet',
#   'dean',
#   'maxwell',
#   'win-a-date',
#   'charity',
#   'auction',
#   'dean',
#   'smart',
#   'suave',
#   'totally',
#   'off-limits',
#   'parker',
#   'dean',
#   'also',
#   'niece',
#   'baby-daddy',
#   'dean',
#   'ran',
#   'parker',
#   'younger',
#   'sister',
#   'told',
#   'pregnancy',
#   'name',
#   'blackballed',
#   'quinn',
#   'family',
#   'ever',
#   'sincebut',
#   'there',
#   'undeniable',
#   'heat',
#   'spark',
#   'parker',
#   'dean',
#   'make',
#   'outrageous',
#   'bid',
#   'body',
#   'whisk',
#   'away',
#   'six-day',
#   'weekend',
#   'inevitable',
#   'happensthis',
#   'erotic',
#   'romance',
#   'didnt',
#   'sit',
#   'well',
#   'many',
#   'niggling',
#   'little',
#   'problem',
#   'entire',
#   'relationship',
#   'couldnt',
#   'let',
#   'mind',
#   'go',
#   'enjoy',
#   'titillating',
#   'romanceto',
#   'start',
#   'parker',
#   'dean',
#   'first',
#   'meeting',
#   'left',
#   'cold',
#   'bump',
#   'one',
#   'another',
#   'win-a-date',
#   'charity',
#   'auction',
#   'dean',
#   'chivalrously',
#   'save',
#   'parker',
#   'grabby',
#   'ex',
#   'following',
#   'exchange',
#   'little',
#   'bit',
#   'heated',
#   'flirtatious',
#   'bordering',
#   'sleazy',
#   'nothing',
#   'parker',
#   'personality',
#   'dean',
#   'hot-n-heavy',
#   'come-on',
#   'found',
#   'endearing',
#   'warranting',
#   'slight',
#   'obsession',
#   'develop',
#   'mean',
#   'obsession',
#   '-',
#   'second',
#   'dean',
#   'learns',
#   'parker',
#   'name',
#   'research',
#   'cant',
#   'stop',
#   'thinking',
#   'concocts',
#   'plan',
#   'win',
#   'space',
#   'hour',
#   'didnt',
#   'get',
#   'fascinating',
#   'parker',
#   'apart',
#   'fact',
#   'dean',
#   'really',
#   'liked',
#   'body',
#   'wanted',
#   'see',
#   'naked',
#   'enjoyed',
#   'chasemore',
#   'anything',
#   'though',
#   'really',
#   'couldnt',
#   'understand',
#   'parker',
#   'attraction',
#   'dean',
#   'mean',
#   'yes',
#   'handsome',
#   'rich',
#   'sophisticated',
#   'also',
#   'impregnated',
#   'abandoned',
#   'little',
#   'sister',
#   'course',
#   'parker',
#   'battle',
#   'half-hearted',
#   'protest',
#   'conscience',
#   'dean',
#   'whisk',
#   'away',
#   'private',
#   'island',
#   'six',
#   'day',
#   'resolve',
#   'quickly',
#   'crumbleswhat',
#   'really',
#   'didnt',
#   'sit',
#   'well',
#   'ann',
#   'bruce',
#   'throw',
#   'money',
#   'moral',
#   'dilemma',
#   'parker',
#   'price',
#   'really',
#   'isnt',
#   'female-empowering',
#   'read',
#   'parker',
#   'pretty',
#   'easily',
#   'drop',
#   'sister',
#   'favour',
#   'dean',
#   'know',
#   'someone',
#   'private',
#   'island',
#   'loaned',
#   'schtick',
#   'parker',
#   'belief',
#   'dean',
#   'left',
#   'sister',
#   'high',
#   'dry',
#   'pregnant',
#   'baby',
#   'im',
#   'saying',
#   'parker',
#   'attraction',
#   'dean',
#   'based',
#   'solely',
#   'asset',
#   'thats',
#   'kind',
#   'came',
#   'across',
#   'im',
#   'sure',
#   'private',
#   'island',
#   'went',
#   'long',
#   'way',
#   'easing',
#   'parker',
#   'guilt',
#   'sleeping',
#   'man',
#   'fathered',
#   'niecethe',
#   'dilemma',
#   'dean',
#   'parenthood',
#   'examined',
#   'second-half',
#   'book',
#   'parker',
#   'confrontation',
#   'dean',
#   'take',
#   'come',
#   '-',
#   'spends',
#   'first',
#   'half',
#   'book',
#   'thinking',
#   'confronting',
#   'raging',
#   'immoral',
#   'shes',
#   'still',
#   'attracted',
#   'want',
#   'sleep',
#   'icki',
#   'never',
#   'liked',
#   'dean',
#   'came',
#   'across',
#   'sleazy',
#   'female',
#   'intuition',
#   'constantly',
#   'red-alerting',
#   'scene',
#   'little',
#   'thing',
#   'added',
#   'not-nice',
#   'protagonist',
#   'though',
#   'bruce',
#   'didnt',
#   'mean',
#   'come',
#   'across',
#   'way',
#   'little',
#   'thing',
#   'like',
#   'undressing',
#   'parker',
#   'arrive',
#   'private',
#   'island',
#   'tucking',
#   'bed',
#   'sleep',
#   'eew',
#   'fact',
#   'kept',
#   'suggestively',
#   'touching',
#   'parker',
#   'even',
#   'firmly',
#   'said',
#   'dont',
#   'dont',
#   'touch',
#   'merunning',
#   'alongside',
#   'parkerdean',
#   'dilemma',
#   'romance',
#   'side-story',
#   'parker',
#   'possibly',
#   'stalked',
#   'find',
#   'apartment',
#   'door',
#   'open',
#   'lingerie',
#   'missing',
#   'drawer',
#   'parker',
#   'obviously',
#   'creeped',
#   'concerned',
#   'stalker',
#   '-',
#   'yet',
#   'dean',
#   'take',
#   'upon',
#   'copy',
#   'made',
#   'apartment',
#   'key',
#   'still',
#   'cant',
#   'help',
#   'attracted',
#   'dont',
#   'think',
#   'dean',
#   'came',
#   'across',
#   'sleazy',
#   'sexual',
#   'predator',
#   'could',
#   'worked',
#   'bruce',
#   'meant',
#   'dean',
#   'not-nice',
#   'anti-hero',
#   'writing',
#   'straight',
#   'romantic',
#   'interest',
#   'compute',
#   'mesorry',
#   'sex',
#   'scene',
#   'hot',
#   'ill',
#   'give',
#   'book',
#   'much',
#   'otherwise',
#   'light',
#   'romantic',
#   'erotica',
#   'work',
#   '-',
#   'could',
#   'never',
#   'get',
#   'past',
#   'parker',
#   'moral',
#   'dilemma',
#   'dean',
#   'sleaziness'],
#  ['34the',
#   'letter',
#   'sweater34',
#   'set',
#   'nc',
#   'always',
#   'one',
#   'favorite',
#   'setting',
#   'especially',
#   'includes',
#   'ocean',
#   'beach',
#   'coastal',
#   'scenery',
#   'character',
#   'somewhat',
#   'realistic',
#   'story',
#   'woven',
#   'around',
#   'long',
#   'lost',
#   'love',
#   'found',
#   'new',
#   'bern',
#   'nc',
#   '30',
#   'year',
#   'span',
#   'enjoyed',
#   'reading',
#   'story',
#   'light',
#   'breezy',
#   'read',
#   'impressed',
#   'mr',
#   'craytons',
#   'tribute',
#   'love',
#   'life',
#   'wife',
#   'jane',
#   'passed',
#   'away',
#   'year',
#   'ago'],
#  ['denise',
#   'agnew',
#   'know',
#   'write',
#   'hot',
#   'military',
#   'men',
#   'book',
#   'exception',
#   'communication',
#   'form',
#   'letter',
#   'eve',
#   'sean',
#   'add',
#   'chemistry',
#   'elevate',
#   'sexual',
#   'tension',
#   'flaming',
#   'intensity',
#   'male',
#   'call',
#   'element',
#   'fun',
#   'sexy',
#   'book',
#   'keep',
#   'wanting',
#   'fortunate',
#   'denise',
#   'agnew',
#   'fan',
#   'book',
#   'hot',
#   'zone',
#   'series',
#   'recommend',
#   'male',
#   'call',
#   'book',
#   'series',
#   'disappointed'],
#  ['accidentally',
#   'ordered',
#   'kindle',
#   'version',
#   'book',
#   'either',
#   'author',
#   'amazon',
#   'kindle',
#   'dropped',
#   'last',
#   '4',
#   'chapter',
#   'kindle',
#   'verson',
#   'good',
#   'book',
#   'l',
#   'rhodes',
#   'beginning',
#   'wrote',
#   'excellent',
#   'novel',
#   'switched',
#   'personal',
#   'opinion',
#   'crank',
#   'mode',
#   'probably',
#   'due',
#   'greed',
#   'shortened',
#   'book',
#   'raised',
#   'price',
#   'refuse',
#   'read',
#   'anything',
#   'name',
#   'author'],
#  ['loved',
#   'every',
#   'novel',
#   'series',
#   '34delaneys',
#   'desert',
#   'sheikh34',
#   'favorite',
#   'knowing',
#   'something',
#   'middle',
#   'eastern',
#   'culture',
#   'since',
#   '911',
#   'realize',
#   'fairy',
#   'tale',
#   'even',
#   'adult',
#   'enjoy',
#   'sexy',
#   'good',
#   'fairy',
#   'tale',
#   'westmoreland',
#   'men',
#   'alpha',
#   'much',
#   'fun',
#   'watch',
#   'fall',
#   'want',
#   'sexy',
#   'read',
#   'highly',
#   'recommend',
#   'novel'],
#  ['havent',
#   'read',
#   'much',
#   'sci-fi',
#   'know',
#   'want',
#   'read',
#   'smiled',
#   'way',
#   'short',
#   'interesting',
#   'story',
#   'story',
#   'set',
#   'intriguing',
#   'world',
#   'loved',
#   'told',
#   'emotion',
#   'hero',
#   'heroine',
#   'werent',
#   'overdone',
#   'told',
#   'rather',
#   'dry',
#   'language',
#   'fit',
#   '-',
#   'world',
#   'live',
#   '-',
#   'perfectlyi',
#   'must',
#   'admit',
#   'immediately',
#   'bought',
#   'second',
#   'book',
#   'series',
#   'hope',
#   'good',
#   'first',
#   'one',
#   '-'],
#  ['could',
#   'get',
#   'story',
#   'femal',
#   'lead',
#   'got',
#   'nerve',
#   'opinion',
#   'menage',
#   'relationship',
#   'hard',
#   'sell',
#   'three',
#   'people',
#   '-',
#   'usually',
#   'two',
#   'men',
#   'one',
#   'woman',
#   'see',
#   'really',
#   'working',
#   'men',
#   'bisexual',
#   'brother',
#   'seems',
#   'ego',
#   'testerone',
#   'would',
#   'big',
#   'issue',
#   'author',
#   'doesnt',
#   'sell',
#   'emotional',
#   'connection',
#   'men',
#   'cant',
#   'imagine',
#   'working',
#   'didnt',
#   'get',
#   'emotional',
#   'connection',
#   'trio'],
#  ['disappointed',
#   'sometimes',
#   'sad',
#   'sometimes',
#   'happy',
#   'always',
#   'keeping',
#   'turning',
#   'page',
#   'definitely',
#   'would',
#   'read',
#   'authoryou',
#   'need',
#   'realize',
#   'set',
#   'time',
#   'past',
#   'set',
#   'stage',
#   'grateful',
#   'live',
#   'nowwonderful',
#   'tale',
#   'keeperthe',
#   'english',
#   'orphansi',
#   'went',
#   'kindle',
#   'store',
#   'downloaded',
#   'several',
#   'book',
#   'cant',
#   'wait',
#   'start',
#   'went',
#   'freebie',
#   'dont',
#   'know',
#   '300',
#   'plus',
#   'book',
#   'would',
#   'formatingenglish',
#   'etc',
#   'may',
#   'better'],
#  ['would',
#   'known',
#   'win',
#   'war',
#   'meth',
#   'need',
#   'good',
#   'guy',
#   'hacker',
#   'enjoyable',
#   'read'],
#  ['loved',
#   'first',
#   'last',
#   'book',
#   'series',
#   'thought',
#   'second',
#   'book',
#   'much',
#   'heavy',
#   'chris',
#   'eliza',
#   'didnt',
#   'nearly',
#   'much',
#   'fun',
#   'kayladylan',
#   'missybrody',
#   'found',
#   'laughing',
#   'loud',
#   'antic',
#   'hot',
#   'bothered',
#   'love',
#   'scene',
#   'plus-size',
#   'woman',
#   'truly',
#   'understand',
#   'insecurity',
#   'though',
#   'brody',
#   'handful',
#   'think',
#   'handled',
#   'fine',
#   'someone',
#   'love',
#   'domineering',
#   'man',
#   'didnt',
#   'problem',
#   'heavy-handednessthis',
#   'quick',
#   'read',
#   'revisiting',
#   'story',
#   'cant',
#   'go',
#   'wrong',
#   'adding',
#   'book',
#   'library'],
#  ['started',
#   'well',
#   'interesting',
#   'relationship',
#   'end',
#   'even',
#   'begin',
#   'would',
#   'love',
#   'read',
#   'story',
#   'flushed',
#   'actual',
#   'book'],
#  ['omfg',
#   'book',
#   'good',
#   'ending',
#   'insane',
#   'favorite',
#   'part',
#   'antonio',
#   'santos',
#   'save',
#   'jane',
#   'book',
#   'deserves',
#   '5',
#   'star',
#   'baby'],
#  ['im',
#   'sure',
#   'author',
#   'garnering',
#   'pity',
#   'mentally',
#   'deranged',
#   'downtrodden',
#   'perhaps',
#   'trying',
#   'convince',
#   'u',
#   'bizarre',
#   'form',
#   'nobility',
#   'resides',
#   'adversity',
#   'either',
#   'case',
#   'served',
#   'large',
#   'dollop',
#   'sanctimonius',
#   'drivel'],
#  ['hand', 'worse', 'book', 'ever', 'read', 'trst', 'say', 'alot'],
#  ['know',
#   'lot',
#   'reviewer',
#   'read',
#   'book',
#   'fully',
#   'realising',
#   'read',
#   'amazon',
#   'review',
#   'knew',
#   'decided',
#   'give',
#   'go',
#   'anywaybasically',
#   'sequel',
#   'doesnt',
#   'work',
#   'standalone',
#   'get',
#   'sequel',
#   'people',
#   'read',
#   'first',
#   'book',
#   'little',
#   'backstory',
#   'never',
#   'hurt',
#   'anyone',
#   'none',
#   'book',
#   'given',
#   'free',
#   'think',
#   'expectation',
#   'would',
#   'people',
#   'introduction',
#   'seriesso',
#   'anyway',
#   'holly',
#   'eight',
#   'month',
#   'pregnant',
#   'married',
#   'three',
#   'brother',
#   'wont',
#   'sex',
#   'theyre',
#   'afraid',
#   'hurting',
#   'babyeventually',
#   'manages',
#   'convince',
#   'ie',
#   'corner',
#   'threaten',
#   'wrath',
#   'hormonal',
#   'woman',
#   'two',
#   'brother',
#   'sex',
#   'one',
#   'sex',
#   'scene',
#   'appear',
#   'book',
#   'fade',
#   'blackeventually',
#   'baby',
#   'everyone',
#   'end',
#   'happily',
#   'ever',
#   'description',
#   'birth',
#   'littlegraphic',
#   'taste',
#   'would',
#   'much',
#   'rather',
#   'read',
#   'second',
#   'sex',
#   'scene',
#   'listen',
#   'one',
#   'brother',
#   'try',
#   'make',
#   'sure',
#   'holly',
#   'passed',
#   'placenta',
#   'shudderwhats',
#   'really',
#   'irritating',
#   'extract',
#   'end',
#   'book',
#   'intriguing',
#   'lack',
#   'characterisation',
#   'backstory',
#   'world-building',
#   'know',
#   'fantasy',
#   'zero',
#   'description',
#   'holly',
#   'location',
#   'surroundings',
#   'mean',
#   'wont',
#   'read',
#   'booki',
#   'finished',
#   'book',
#   'mercifully',
#   'short',
#   'would',
#   'felt',
#   'guilty',
#   'giving',
#   'short',
#   'story'],
#  ['im',
#   'generally',
#   'reluctant',
#   'take',
#   'chance',
#   'unknown',
#   'unrecommended',
#   'author',
#   'good',
#   'review',
#   'price',
#   'prompted',
#   'give',
#   'one',
#   'shot',
#   'im',
#   'really',
#   'glad',
#   'didcassandra',
#   'think',
#   'know',
#   'exactly',
#   'shes',
#   'looking',
#   'man',
#   'tall',
#   'dark',
#   'handsome',
#   'side',
#   'good',
#   'bed',
#   'shes',
#   'busy',
#   'trying',
#   'secure',
#   'almost',
#   'completely',
#   'dismisses',
#   'heat',
#   'coming',
#   'another',
#   'source',
#   'laveys',
#   'humor',
#   'really',
#   'shine',
#   'one',
#   'heroine',
#   'stuck',
#   'cloud',
#   'hero',
#   'who',
#   'running',
#   'attraction',
#   'isnt',
#   'nicemy',
#   'complaint',
#   'would',
#   'cassandra',
#   'lost',
#   'cloud',
#   'moment',
#   'go',
#   'little',
#   'long',
#   'tastehonestly',
#   'lavey',
#   'undercharging',
#   'adventure',
#   'though',
#   'short',
#   'well-written',
#   'well-edited',
#   'highly',
#   'recommend',
#   'look',
#   'forward',
#   'seeing',
#   'future'],
#  ['story',
#   'start',
#   'immediately',
#   'sex',
#   'may',
#   'may',
#   'work',
#   'focus',
#   'voyeurism',
#   'light',
#   'bdsm',
#   'weak',
#   'diluted',
#   'story',
#   'jump',
#   'right',
#   'sex',
#   'sexier',
#   'inline',
#   'subject',
#   'matter',
#   'simply',
#   'state',
#   'hotter',
#   'story',
#   'better',
#   'defined',
#   'straddle',
#   'try',
#   'erotic',
#   'story',
#   'sexy',
#   'hot',
#   'romp',
#   'fails'],
#  ['interesting',
#   'read',
#   'perspective',
#   'bible',
#   'history',
#   'good',
#   'addition',
#   'book',
#   'commentary',
#   'spiritual',
#   'reference',
#   'library',
#   'good',
#   'quality',
#   'easy',
#   'read',
#   'translation'],
#  ['leanne', 'bank', 'good', 'author', 'wait', 'read', 'book', 'two', 'thumb'],
#  ['gave',
#   'book',
#   '3',
#   'star',
#   'simply',
#   'writing',
#   'little',
#   'awkward',
#   'punctuation',
#   'hard',
#   'follow',
#   'maybe',
#   'edited',
#   'non-english',
#   'language',
#   'editor',
#   'anyway',
#   'detracts',
#   'story',
#   'still',
#   'interesting',
#   'light',
#   'enough',
#   'read',
#   'first',
#   'book',
#   'bought',
#   'four',
#   'series',
#   'guess',
#   'say',
#   'good',
#   'enough',
#   'grab',
#   'reader',
#   'henry',
#   'wright',
#   'retired',
#   'police',
#   'chief',
#   'retired',
#   'palm',
#   'spring',
#   'find',
#   'lot',
#   'murder',
#   'help',
#   'solve',
#   'due',
#   'ineptness',
#   'good',
#   'friend',
#   'local',
#   'police',
#   'chief',
#   'like',
#   'book',
#   'recommend',
#   'price',
#   'right'],
#  ['short',
#   'humorous',
#   'page',
#   'turner',
#   'managed',
#   'convey',
#   'christmas',
#   'spirit',
#   'develop',
#   'character',
#   'well',
#   'include',
#   'frivolity',
#   'space',
#   'page',
#   'author',
#   'wonderful',
#   'job',
#   'putting',
#   'reader',
#   'center',
#   'action',
#   'regardless',
#   'action',
#   'might',
#   'entail',
#   'bright',
#   'whitty',
#   'packed',
#   'family',
#   'eccentricitiesyoull',
#   'find',
#   'caught',
#   'fun'],
#  ['delilah',
#   'princess',
#   'strong',
#   'independent',
#   'rug',
#   'pulled',
#   'told',
#   'father',
#   'arranging',
#   'marriage',
#   'two',
#   'men',
#   '--',
#   'one',
#   'childhood',
#   'friend',
#   'arrogant',
#   'stranger',
#   '--',
#   'all',
#   'attempt',
#   'unite',
#   'two',
#   'kingdom',
#   'falcon',
#   'kingdom',
#   'cant',
#   'believe',
#   'thatpierce',
#   'prince',
#   'tiger',
#   'kingdom',
#   'jason',
#   'prince',
#   'lion',
#   'kingdom',
#   'couple',
#   'quite',
#   'decided',
#   'delilah',
#   'person',
#   'make',
#   'triad',
#   'bad',
#   'isnt',
#   'willing',
#   'go',
#   'along',
#   'dealon',
#   'wedding',
#   'day',
#   'delilah',
#   'changed',
#   'plan',
#   'taken',
#   'flight',
#   'pierce',
#   'jason',
#   'track',
#   'capture',
#   'mate',
#   'true',
#   'bonding',
#   'triad',
#   'delilah',
#   'instant',
#   'dislike',
#   'idea',
#   'partner',
#   'doom',
#   'beginstheirs',
#   'capture',
#   'brings',
#   'three',
#   'different',
#   'shifter',
#   'mating',
#   'least',
#   'two',
#   'happy',
#   'however',
#   'delilah',
#   'determined',
#   'escape',
#   'fate',
#   'found',
#   'sexual',
#   'encounter',
#   'erotic',
#   'finally',
#   'join',
#   'true',
#   'mating',
#   'brought',
#   'together',
#   'whole',
#   'like',
#   'pierce',
#   'jason',
#   'always',
#   'wanted',
#   'reading',
#   'blurb',
#   'way',
#   'delilah',
#   'began',
#   'expected',
#   'weakly',
#   'giving',
#   'obvious',
#   'anger',
#   'way',
#   'showing',
#   'shock',
#   'future',
#   'said',
#   'capture',
#   'erotic',
#   'story',
#   'perfect',
#   'away',
#   'afternoon',
#   'eveningjoreviewed',
#   'joyfully',
#   'reviewed'],
#  ['wasnt',
#   'overly',
#   'impressed',
#   'story',
#   'plot',
#   'character',
#   'basically',
#   'definitely',
#   'would',
#   'suggest',
#   'book',
#   'anyone'],
#  ['book',
#   'really',
#   'pretty',
#   'good',
#   'right',
#   'ending',
#   'abolute',
#   'disappointment',
#   'would',
#   'recommend',
#   'paying',
#   'book',
#   'read',
#   'free',
#   'dont',
#   'bother',
#   'last',
#   'chapter',
#   'author',
#   'didnt',
#   'bother',
#   'either'],
#  ['something',
#   'book',
#   'seems',
#   'fall',
#   'short',
#   'character',
#   'interesting',
#   'enough',
#   'seem',
#   'lose',
#   'focus',
#   'story',
#   'go',
#   'like',
#   'b',
#   'movie',
#   'find',
#   'weirdly',
#   'attracted',
#   'lackluster',
#   'story',
#   'seems',
#   'little',
#   'far',
#   'fetched'],
#  ['enjoyed',
#   'reading',
#   'three',
#   'book',
#   'series',
#   'linked',
#   'character',
#   'around',
#   'caring',
#   'character',
#   'past',
#   'captured',
#   'well',
#   'merging',
#   'life',
#   'across',
#   'story',
#   'reading',
#   'three',
#   'book'],
#  ['well',
#   'written',
#   'book',
#   'didnt',
#   'want',
#   'put',
#   'ill',
#   'read',
#   'author',
#   'minor',
#   'complaint',
#   'short',
#   'section',
#   'font',
#   'changed',
#   'may',
#   'ebooks'],
#  ['story',
#   'pretty',
#   'much',
#   'expect',
#   'sizzling',
#   'hot',
#   'read',
#   'beginning',
#   'end',
#   'enough',
#   'romance',
#   'keep',
#   'scandalous',
#   'character',
#   'likable',
#   'root',
#   'together',
#   'conflict',
#   'get',
#   'solved',
#   'little',
#   'easily',
#   'neatly',
#   'serious',
#   'conflict',
#   'plot',
#   'story',
#   'intended',
#   'bethe',
#   'navy',
#   'seal',
#   'supporting',
#   'men',
#   'promise',
#   'great',
#   'lead',
#   'romp',
#   'future',
#   'story'],
#  ['serious',
#   'contemplation',
#   'opinion',
#   'sensitive',
#   'reader',
#   'may',
#   'want',
#   'take',
#   'pas',
#   'uneven',
#   'place',
#   'somewhat',
#   'unpleasant',
#   'bookpart',
#   'problem',
#   'subject',
#   'matter',
#   'part',
#   'uneven',
#   'writing',
#   'part',
#   'character',
#   'homicide',
#   'inspector',
#   'john',
#   'richetti',
#   'highly-stressed',
#   'hard-drinking',
#   'policeman',
#   'caught',
#   'jonestown',
#   'cult',
#   'child',
#   '70',
#   '--',
#   'one',
#   '900',
#   'people',
#   'drank',
#   'kool-aidat',
#   'time',
#   'richetti',
#   'dimwitted',
#   'irresponsible',
#   'even',
#   'undercover',
#   'partner',
#   'call',
#   'stupid',
#   'bastard',
#   'here',
#   'one',
#   'example',
#   'give',
#   'seven',
#   'sleeping',
#   'pill',
#   '--',
#   'seven',
#   '--',
#   'cult',
#   'member',
#   'used',
#   'taking',
#   'isnt',
#   'bad',
#   'guy',
#   'person',
#   'almost',
#   'doesnt',
#   'wake',
#   'here',
#   'another',
#   'despite',
#   'specifically',
#   'warned',
#   'tell',
#   'truth',
#   'admitting',
#   'personal',
#   'weakness',
#   'let',
#   'cult',
#   'get',
#   'hook',
#   'openly',
#   'admits',
#   'involvement',
#   'jamestown',
#   'always',
#   'know',
#   'best',
#   'he',
#   'always',
#   'wrongin',
#   'fact',
#   'neither',
#   'investigator',
#   'richetti',
#   'marilyn',
#   'michaelsen',
#   'police',
#   'department',
#   'psychologist',
#   'accompanies',
#   'cover',
#   'task',
#   '--',
#   'supremely',
#   'dangerous',
#   'job',
#   'infiltrating',
#   'earthbound',
#   'cult',
#   'bringing',
#   'two',
#   'suspected',
#   'murderer',
#   'justice',
#   'least',
#   'michaelsen',
#   'brain',
#   'self',
#   'control',
#   'richetti',
#   'foolbut',
#   'here',
#   'crux',
#   'itif',
#   'youre',
#   'touchy',
#   'abusive',
#   'situation',
#   'involving',
#   'child',
#   'violent',
#   'rape',
#   'coercive',
#   'act',
#   'involving',
#   'feces',
#   'im',
#   'sorry',
#   'there',
#   'oblique',
#   'way',
#   'say',
#   'really',
#   'consider',
#   'giving',
#   'book',
#   'wide',
#   'berth',
#   'part',
#   'forced',
#   'coprophagia',
#   'two-thirds',
#   'way',
#   '--',
#   'hey',
#   'youre',
#   'going',
#   'look',
#   'im',
#   'defining',
#   '--',
#   'almost',
#   'put',
#   'book',
#   'disgust',
#   'end',
#   'im',
#   'sure',
#   'shouldnt',
#   'stopped',
#   'tolerance',
#   'kind',
#   'writing',
#   'may',
#   'vary',
#   'course'],
#  ['positive',
#   'book',
#   'well',
#   'written',
#   'tight',
#   'scene',
#   'well-developed',
#   'charactersthe',
#   'negative',
#   'could',
#   'bring',
#   'like',
#   'briony',
#   'constant',
#   'daydream',
#   'perfect',
#   'master',
#   'quickly',
#   'became',
#   'irritating',
#   'well',
#   'highlighting',
#   'shallow',
#   'materialism',
#   'many',
#   'insertion',
#   'e-mail',
#   'online',
#   'bdsm',
#   'dating',
#   'website',
#   'disturbing',
#   'really',
#   'didnt',
#   'add',
#   'story',
#   'chris',
#   'briony',
#   'fact',
#   'majority',
#   'story',
#   'wasnt',
#   'relationship',
#   'chris',
#   'briony',
#   'briony',
#   'neurotic',
#   'need',
#   'find',
#   'one',
#   'destructive',
#   'behavior',
#   'indulgesi',
#   'completely',
#   'agree',
#   'previous',
#   'reviewer',
#   'mentioned',
#   'first-hand',
#   'style',
#   'writing',
#   'hampered',
#   'story',
#   'found',
#   'difficult',
#   'understand',
#   'chris',
#   'would',
#   'want',
#   'briony',
#   'clue',
#   'thought'],
#  ['hello',
#   'anyone',
#   'read',
#   'im',
#   'stop',
#   'making',
#   'purchase',
#   'something',
#   'might',
#   'regret',
#   'im',
#   'book',
#   'person',
#   'book',
#   'alright',
#   'nearly',
#   '65',
#   'book',
#   'creeping',
#   'around',
#   'dark',
#   'ship',
#   'trying',
#   'figure',
#   'whether',
#   'alien',
#   'origin',
#   'whether',
#   'theyre',
#   'alone',
#   'ship',
#   'one',
#   'minute',
#   'think',
#   'alien',
#   'next',
#   'exact',
#   'opposite',
#   'deadly',
#   'enemy',
#   'talking',
#   'deadly',
#   'original',
#   'get',
#   'point',
#   'overall',
#   'great',
#   'im',
#   'real',
#   'huge',
#   'fan',
#   'military',
#   'story',
#   'flop',
#   'could',
#   'better',
#   'could',
#   'done',
#   'middle',
#   'keep',
#   'amused'],
#  ['book',
#   'short',
#   'sweet',
#   'josephine',
#   'blake',
#   'relationship',
#   'hot',
#   'sweet',
#   'unforgettable',
#   'night',
#   'together',
#   'blake',
#   'insecurity',
#   'stopped',
#   'might',
#   'drove',
#   'josephine',
#   'philandering',
#   'cousin',
#   'hand',
#   'tragedy',
#   'brought',
#   'together',
#   'blake',
#   'everything',
#   'keep',
#   'relationship',
#   'sweet',
#   'ended',
#   'nicely',
#   'wish'],
#  ['look',
#   'appreciate',
#   'great',
#   'short',
#   'story',
#   'novella',
#   'even',
#   'gee',
#   'remember',
#   'novella',
#   'called',
#   'short',
#   'story',
#   'found',
#   'way',
#   'write',
#   'even',
#   'le',
#   'still',
#   'charge',
#   'u',
#   'paying',
#   '520',
#   'short',
#   'story',
#   'read',
#   'free',
#   'sample',
#   'would',
#   'paid',
#   '099',
#   'whole',
#   'story',
#   'lot',
#   'nerve',
#   'asking',
#   'little',
#   'really',
#   'esp',
#   'digital',
#   'book',
#   'cmon',
#   'normally',
#   'wouldnt',
#   'wrtie',
#   'review',
#   'something',
#   'read',
#   'completely',
#   'unless',
#   'bad',
#   'couldnt',
#   'make',
#   'finish',
#   'case',
#   'writing',
#   'protesting',
#   'publisher',
#   'expectation',
#   'stupid',
#   'enough',
#   'pay',
#   'much',
#   'short',
#   'story',
#   'dont',
#   'complain',
#   'one',
#   'way',
#   'available',
#   'u',
#   'make',
#   'impact',
#   'else',
#   'aside',
#   'purchasing',
#   'take',
#   'stand'],
#  ['read',
#   'lot',
#   'romance',
#   'novel',
#   '-',
#   'ive',
#   'read',
#   'lot',
#   'bad',
#   'romance',
#   'novel',
#   'usually',
#   'finish',
#   'whatever',
#   'reading',
#   'book',
#   'tiresome',
#   'boring',
#   'started',
#   'randomly',
#   'skipping',
#   'page',
#   'around',
#   'middle',
#   'book',
#   'whatever',
#   'reason',
#   'wanted',
#   'sort',
#   'resolution',
#   'skimmed',
#   'way',
#   'end',
#   'tiresome',
#   'readi',
#   'thought',
#   'roxy',
#   'ridiculous',
#   'top',
#   'reading',
#   'constant',
#   'description',
#   'clothing',
#   'top',
#   'made',
#   'wonder',
#   'didnt',
#   'call',
#   'dolly',
#   'parton',
#   'model',
#   'didnt',
#   'like',
#   'roxy',
#   'mother',
#   'zaynes',
#   'mother',
#   'zayne',
#   'tolerable',
#   'really',
#   'modern',
#   'day',
#   'tomoato',
#   'farmer',
#   'living',
#   '10',
#   'minute',
#   'nashville',
#   'hard',
#   'time',
#   'accepting',
#   'book'],
#  ['really',
#   'like',
#   'short',
#   'story',
#   'book',
#   'kindle',
#   'store',
#   'description',
#   'didnt',
#   'give',
#   'length',
#   'read',
#   'hour',
#   'way',
#   'fast',
#   'paced',
#   'real',
#   'development',
#   'story',
#   'character',
#   'wasnt',
#   'exciting',
#   'language',
#   'really',
#   'cheesy',
#   'really',
#   'believable',
#   '34historical34',
#   'romance',
#   'mallery',
#   'stick',
#   'modern',
#   'setting',
#   'actual',
#   'novel',
#   'im',
#   'usually',
#   'fan',
#   'disappointingi',
#   'understand',
#   'meant',
#   'set',
#   'series',
#   'however',
#   'dont',
#   'think',
#   'story',
#   'necessary',
#   'set',
#   'hundred',
#   'year',
#   'series',
#   'instead',
#   'start',
#   'poor',
#   'note',
#   'read',
#   'series',
#   'yet',
#   'give',
#   'first',
#   'book',
#   'try',
#   'hope',
#   'improve',
#   'recommend',
#   'storythose',
#   'interested',
#   'series',
#   'start',
#   'book',
#   'one',
#   'skip'],
#  ['overall',
#   'reviewi',
#   'picked',
#   'offered',
#   'free',
#   'actually',
#   'enjoyed',
#   'thought',
#   'would',
#   'thiswas',
#   'quick',
#   'enjoyable',
#   'albeit',
#   'predictable',
#   'read',
#   'hey',
#   'else',
#   'would',
#   'expect',
#   'harlequinwhat',
#   'likedi',
#   'enjoyed',
#   'rekindling',
#   'past',
#   'love',
#   'many',
#   'year',
#   'latergood',
#   'character',
#   'development',
#   'shifting',
#   'povi',
#   'enjoyed',
#   'medical',
#   'settingstorylinewhat',
#   'didnt',
#   'likei',
#   'must',
#   'confess',
#   'title',
#   'real',
#   'turn',
#   'come',
#   'thingspredictable',
#   'ending',
#   'probably',
#   'shouldnt',
#   'hold',
#   'author',
#   'romance',
#   'genre',
#   'formula',
#   'fiction',
#   'alltoo',
#   'many',
#   'exclamation',
#   'pointstoo',
#   'short',
#   'overall',
#   'story',
#   'would',
#   'enhanced',
#   'extra',
#   'scene',
#   'allow',
#   'greater',
#   'character',
#   'plot',
#   'development'],
#  ['predominant',
#   'issue',
#   'book',
#   'editing',
#   'every',
#   'sentence',
#   'run-on',
#   'sentence',
#   'tried',
#   'ignore',
#   'reading',
#   'literary',
#   'equivalent',
#   'tumbling',
#   'hill',
#   'one',
#   'page',
#   'average',
#   'sentence',
#   'five',
#   'six',
#   'line',
#   'long',
#   '--',
#   'joined',
#   'together',
#   'comma',
#   'difficult',
#   'follow',
#   'comfortablyputting',
#   'aside',
#   'editing',
#   'issue',
#   'know',
#   'author',
#   'aware',
#   'hasnt',
#   'yet',
#   'fixed',
#   'novel',
#   'would',
#   '25',
#   '3',
#   'star',
#   'basic',
#   'premise',
#   'book',
#   '--',
#   'retired',
#   'police',
#   'chief',
#   'wisconsin',
#   'help',
#   'solve',
#   'mystery',
#   'palm',
#   'spring',
#   '--',
#   'isnt',
#   'bad',
#   'actual',
#   'mechanic',
#   'leave',
#   'question',
#   'need',
#   'back',
#   'story',
#   'help',
#   'understand',
#   'small',
#   'town',
#   'police',
#   'chief',
#   'would',
#   'ability',
#   'especially',
#   'good',
#   'solving',
#   'mystery',
#   'story',
#   'natural',
#   'profiling',
#   'even',
#   'freelance',
#   'profiling',
#   'fbi',
#   'didnt',
#   'ring',
#   'true',
#   'never',
#   'really',
#   'saw',
#   'henry',
#   'good',
#   'figuring',
#   'thing',
#   'special',
#   'insight',
#   'people',
#   'sort',
#   'talk',
#   'people',
#   'mystery',
#   'solves',
#   'kind',
#   'like',
#   'watching',
#   'grandpa',
#   'solve',
#   'case',
#   '--',
#   'detective',
#   'grandpa',
#   'regular',
#   'grandpai',
#   'also',
#   'lingering',
#   'question',
#   'plot',
#   'device',
#   'autographed',
#   'picture',
#   'didnt',
#   'make',
#   'sense',
#   'dont',
#   'understand',
#   'somebody',
#   'would',
#   'likely',
#   'buy',
#   'house',
#   'autographed',
#   'picture',
#   'celebrity',
#   'either',
#   'youre',
#   'easy',
#   'mark',
#   'sort',
#   'scam',
#   'arent',
#   'picture',
#   'supposed',
#   'convey',
#   '--',
#   'celebrity',
#   'left',
#   'autographed',
#   'picture',
#   'moving',
#   'also',
#   'didnt',
#   'make',
#   'sense',
#   'nobody',
#   'police',
#   'force',
#   'wanted',
#   'solve',
#   'crime',
#   'theyd',
#   'heard',
#   'rumor',
#   'victim',
#   'liked',
#   'sex',
#   'teenage',
#   'boy',
#   'detective',
#   'cant',
#   'opt',
#   'murder',
#   'investigation',
#   '--',
#   'may',
#   'halfway',
#   'job',
#   'cant',
#   'call',
#   'local',
#   'volunteeri',
#   'give',
#   'author',
#   'credit',
#   'attempting',
#   'create',
#   'character',
#   'add',
#   'life',
#   'book',
#   'wayne',
#   'henry',
#   'alike',
#   'distinguishable',
#   '--',
#   'need',
#   'able',
#   'play',
#   'better',
#   'going',
#   'successful',
#   'series',
#   'charles',
#   'actually',
#   'good',
#   'character',
#   'see',
#   'potential',
#   'jarring',
#   'continually',
#   'introduce',
#   'heeey',
#   'dialogue',
#   'sort',
#   'spelling',
#   'alteration',
#   'imply',
#   'dialect',
#   'distracting',
#   'unnecessary',
#   'character',
#   'amit',
#   'interesting',
#   'could',
#   'see',
#   'author',
#   'attempt',
#   'surround',
#   'henry',
#   'character',
#   'different',
#   '--',
#   'amit',
#   'young',
#   'different',
#   'race',
#   'nationality',
#   'technically',
#   'savvy',
#   'different',
#   'personality',
#   'like',
#   'vast',
#   'majority',
#   'dialogue',
#   'amits',
#   'didnt',
#   'ring',
#   'true',
#   'work',
#   'development',
#   'dialogue',
#   'character',
#   'see',
#   'solid',
#   'group',
#   'hoping',
#   'maybe',
#   'amit',
#   'set',
#   'regular',
#   'characterthis',
#   'potential',
#   'good',
#   'series',
#   'isnt',
#   'yet',
#   'would',
#   'check',
#   'future',
#   'book',
#   'felt',
#   'author',
#   'addressed',
#   'editing',
#   'tightened',
#   'plot',
#   'focused',
#   'characterization',
#   'think',
#   'room',
#   'mystery',
#   'world',
#   'detective',
#   'like',
#   'henry'],
#  ['first',
#   'say',
#   'cover',
#   'match',
#   'content',
#   'book',
#   'highly',
#   'suggest',
#   'changing',
#   'nearly',
#   'read',
#   'book',
#   'based',
#   'cover',
#   'saw',
#   'review',
#   'mentioned',
#   'match',
#   'decided',
#   'give',
#   'gonow',
#   'say',
#   'book',
#   'simply',
#   'beautiful',
#   'sure',
#   'else',
#   'describe',
#   'subject',
#   'handled',
#   'tenderness',
#   'pignancy',
#   'author',
#   'achieve',
#   'aware',
#   'tear',
#   'jerker',
#   'boy',
#   'cry',
#   'cry',
#   'cry',
#   'cry',
#   'process',
#   'cathartic',
#   'way',
#   'felt',
#   'spiritual',
#   'journey',
#   'love',
#   'affair',
#   'ocean',
#   'story',
#   'resonated',
#   'even',
#   'deeper',
#   'learned',
#   'story',
#   'learned',
#   'lesson',
#   'often',
#   'take',
#   'lifetime',
#   'learn',
#   'lesson',
#   'truly',
#   'living',
#   'suggest',
#   'book',
#   'anyone',
#   'interested',
#   'learning'],
#  ['loved',
#   'book',
#   'charactersthe',
#   'story',
#   'flowed',
#   'perfectly',
#   'scene',
#   'scenemake',
#   'movie'],
#  ['havent',
#   'yet',
#   'read',
#   'grimm',
#   'tale',
#   'heard',
#   'please',
#   'take',
#   'time',
#   'sit',
#   'see',
#   'age',
#   'fairy',
#   'tale',
#   'telling',
#   'produced',
#   'early',
#   'day',
#   'basis',
#   'many',
#   'modern',
#   'day',
#   'tale',
#   'written'],
#  ['cant',
#   'wait',
#   'read',
#   'next',
#   'book',
#   'series',
#   'could',
#   'find',
#   'lovely',
#   'men',
#   'like',
#   'thesepass',
#   'ice'],
#  ['written',
#   'language',
#   'structure',
#   'reminiscent',
#   'king',
#   'james',
#   'bible',
#   'author',
#   'point',
#   'unlawful',
#   'hurtful',
#   'vestige',
#   'secrecy',
#   'maybe',
#   'considered',
#   'past',
#   'destruction',
#   'secrecy',
#   'organized',
#   'religion',
#   'note',
#   'terrible',
#   'freemasonry',
#   'member',
#   'one',
#   'pay',
#   'membership',
#   'fee',
#   'hogwash',
#   'open',
#   'eye',
#   'ask',
#   'catholic',
#   'church',
#   'destroying',
#   'member',
#   'family',
#   'deny',
#   'god',
#   'sacrament',
#   'subject',
#   'manmade',
#   'rule',
#   'parishoner',
#   'doesnt',
#   'pay',
#   'annulment',
#   'sure',
#   'money',
#   'admin',
#   'feesa',
#   'joke',
#   'cry',
#   'continually',
#   'money',
#   'reference',
#   'fee',
#   'around',
#   'also',
#   'disgusting',
#   'performance',
#   'organized',
#   'pastor',
#   'hide',
#   'sin',
#   'secrecy',
#   'secretly',
#   'plan',
#   'continually',
#   'beg',
#   'money',
#   'patron',
#   'lowest',
#   'financial',
#   'level',
#   'receive',
#   'none',
#   'church',
#   'pastor',
#   'blatantly',
#   'hold',
#   'hand',
#   'stop',
#   'using',
#   'christ',
#   'name',
#   'justify',
#   'thievery',
#   'also',
#   'stop',
#   'pedophilia',
#   'ill',
#   'donate',
#   'directly',
#   'needy',
#   'without',
#   'church',
#   'guilt',
#   'lie'],
#  ['possible',
#   'spoilersafter',
#   'reading',
#   'review',
#   'book',
#   'almost',
#   'didnt',
#   'read',
#   'fan',
#   'relationship',
#   'people',
#   'large',
#   'gap',
#   'age',
#   'especially',
#   'minor',
#   'well',
#   'reading',
#   'book',
#   'wasnt',
#   'bothered',
#   'felt',
#   'detracted',
#   'intriguing',
#   'storyline',
#   'utterly',
#   'ignorant',
#   'reason',
#   'camp',
#   'abstinence',
#   'camp',
# ...
#   'taran',
#   'houston',
#   'pd',
#   'detective',
#   'take',
#   'upon',
#   'protect',
#   'lark',
#   'close',
#   'quarter',
#   'heated',
#   'emotion',
#   'might',
#   'play',
#   'little',
#   'much',
#   'though',
#   'secret',
#   'come',
#   '-',
#   'hidden',
#   'feeling',
#   'revealedcan',
#   'get',
#   'taran',
#   'yum',
#   'definitely',
#   'fun',
#   'entertaining',
#   'read',
#   'fan',
#   'hero',
#   'heroine',
#   'went',
#   'along',
#   'book',
#   'kept',
#   'glued',
#   'throughout',
#   'one',
#   'dip',
#   'boredom',
#   'one',
#   'great',
#   'thing',
#   'kindle',
#   'iphone',
#   '-',
#   'reading',
#   'line',
#   'picking',
#   'drama',
#   'queen',
#   'reading',
#   'football',
#   'game',
#   'reading',
#   'line',
#   'grocery',
#   'storereading',
#   'im',
#   'web',
#   'upload',
#   'work',
#   'couldnt',
#   'put',
#   'niggle',
#   'negative',
#   'one',
#   'ending',
#   '-',
#   'ill',
#   'try',
#   'keep',
#   'spoiler',
#   'free',
#   'bit',
#   'unresolved',
#   'conflict',
#   'wanted',
#   'see',
#   'outcome',
#   'particular',
#   'plot',
#   'thread',
#   'never',
#   'happened',
#   'least',
#   'quick',
#   'epilogue',
#   'tidied',
#   'everything',
#   'thats',
#   'though',
#   'wasnt',
#   'big',
#   'deal',
#   'main',
#   'feature',
#   'resolved',
#   'matteredrecommendations',
#   'adult',
#   'lot',
#   'happy',
#   'coupling',
#   'pnr',
#   'fan',
#   'werewolf',
#   'fan',
#   'enjoy',
#   'werewolf',
#   'book',
#   'paranormal',
#   'element',
#   'over-powering',
#   'would',
#   'good',
#   'contemporary',
#   'pnr',
#   'transition',
#   'book'],
#  ['loved',
#   'story',
#   'two',
#   'main',
#   'character',
#   'cute',
#   'together',
#   'bit',
#   'drama',
#   'buy',
#   'loved',
#   'reading'],
#  ['purchased',
#   'digital',
#   'book',
#   'kate',
#   'pearce',
#   'second',
#   'book',
#   'read',
#   'erotic',
#   'scene',
#   'book',
#   'unparalled',
#   'author',
#   'flash',
#   'back',
#   'heroine',
#   'misspent',
#   'youth',
#   'time',
#   'spent',
#   'betweenwith',
#   'two',
#   'lover',
#   'twin',
#   'nothing',
#   'could',
#   'much',
#   'taboo',
#   'forbidden',
#   'nature',
#   'romance',
#   'kept',
#   'turning',
#   'page',
#   'sex',
#   'scene',
#   'helped',
#   'devour',
#   'book',
#   'complaint',
#   'novel',
#   'wasnt',
#   'long',
#   'enough',
#   'also',
#   'offended',
#   'uncle',
#   'belief',
#   'woman',
#   'cant',
#   'bear',
#   'child',
#   'kinda',
#   'worthless',
#   'author',
#   'defense',
#   'kinda',
#   'par',
#   'course',
#   'time',
#   'period'],
#  ['emily',
#   'jake',
#   'adventure',
#   'discovering',
#   'forever',
#   'kind',
#   'love',
#   'heartwarming',
#   'emily',
#   'decides',
#   'life',
#   'outside',
#   'work',
#   'problem',
#   'firework',
#   'begin',
#   'jake',
#   'resists',
#   'forever',
#   'relationship',
#   'often',
#   'line',
#   'pat',
#   'sparrow',
#   'take',
#   'flight',
#   'first',
#   'absolutely',
#   'loved',
#   'hearing',
#   'jakes',
#   'thought'],
#  ['pat',
#   'back',
#   'homosexuality',
#   'main',
#   'theme',
#   'book',
#   'repeated',
#   'many',
#   'time',
#   'nothing',
#   'wrong',
#   'gay',
#   'tell',
#   'jesus',
#   'aint',
#   'buying'],
#  ['like',
#   'old-fashioned',
#   'western',
#   'like',
#   'read',
#   'zane',
#   'grey',
#   'particularly',
#   'good',
#   'writer',
#   'many',
#   'rip-roarin',
#   'western',
#   'rightly',
#   'become',
#   'classic',
#   'aware',
#   'goodly',
#   'number',
#   'book',
#   'prairie',
#   'romance',
#   'action-packed',
#   'western',
#   'there',
#   'often',
#   'huff',
#   'bluff',
#   'gunfire',
#   'many',
#   'book',
#   'set',
#   'old',
#   'west',
#   'past',
#   'modern',
#   'time',
#   'meaning',
#   'contemporary',
#   'wrote',
#   'often',
#   'depicted',
#   'rugged',
#   'male',
#   'abiding',
#   'highly',
#   'developed',
#   'sense',
#   'fair-play',
#   'moral',
#   'integrity',
#   'contrast',
#   'sneaky',
#   'villain',
#   'chaste',
#   'female',
#   'heroine',
#   'misunderstanding',
#   'romance',
#   'overall',
#   'wholesomeness',
#   'leading',
#   'happy',
#   'ending',
#   'several',
#   'work',
#   'collection',
#   '--',
#   'though',
#   'may',
#   'set',
#   'western',
#   'states',
#   '--',
#   'are',
#   'would',
#   'normally',
#   'call',
#   'western',
#   'others',
#   'baseball',
#   'story',
#   'nonfiction',
#   'account',
#   'fishing',
#   'camping',
#   'sadly',
#   'majority',
#   'greatest',
#   'western',
#   'yet',
#   'inexpensively',
#   'freely',
#   'available',
#   'public',
#   'domain',
#   'edition',
#   'matter',
#   'wrote',
#   'prairie',
#   'romance',
#   'baseball',
#   'story',
#   'fishing',
#   'account',
#   'classic',
#   'western',
#   'grey',
#   'knew',
#   'tell',
#   'good',
#   'story',
#   'vivid',
#   'description',
#   'second',
#   'noneupdate',
#   '05-08-13',
#   'may',
#   'wish',
#   'compare',
#   'set',
#   '26',
#   'another',
#   'zane',
#   'grey',
#   'collection',
#   'recently',
#   'published',
#   'wildside',
#   'press',
#   'zane',
#   'grey',
#   'megapack',
#   'attractively',
#   'formatted',
#   'offering',
#   '42',
#   'novel',
#   'story',
#   '99',
#   'seems',
#   'like',
#   'better',
#   'deal'],
#  ['two', 'word', 'book', 'rest', 'book', 'rough', 'rider', 'seriesloved'],
#  ['interesting',
#   'read',
#   'point',
#   'view',
#   'pastor',
#   'slavery',
#   'however',
#   'seemed',
#   'little',
#   'contrived',
#   'real',
#   'situation',
#   'clear'],
#  ['okay',
#   'started',
#   'stopped',
#   'book',
#   'several',
#   'time',
#   'mainly',
#   'editing',
#   'horrific',
#   'dont',
#   'even',
#   'know',
#   'edited',
#   'grammatical',
#   'error',
#   'misspelled',
#   'word',
#   'word',
#   'wrong',
#   'order',
#   'book',
#   'time',
#   'seems',
#   'written',
#   'first',
#   'second',
#   'even',
#   'third',
#   'point',
#   'view',
#   'kindle',
#   'version',
#   'even',
#   'different',
#   'font',
#   'alternating',
#   'throughout',
#   'took',
#   'away',
#   'story',
#   'mistake',
#   'got',
#   'even',
#   'worse',
#   'closer',
#   'got',
#   'end',
#   'bookthe',
#   'plot',
#   'seemed',
#   'undeveloped',
#   'heroinekat',
#   'saw',
#   'mother',
#   'murdered',
#   'sent',
#   'father',
#   'raised',
#   'uncle',
#   'hope',
#   'would',
#   'keep',
#   'safe',
#   'safer',
#   'never',
#   'explained',
#   'meet',
#   'boy',
#   'kenji',
#   'fall',
#   'love',
#   'kenji',
#   'go',
#   'away',
#   'year',
#   'later',
#   'kat',
#   'reintroduced',
#   'told',
#   'must',
#   'marry',
#   'per',
#   'agreement',
#   'family',
#   'made',
#   'born',
#   'premise',
#   'power',
#   'used',
#   'fight',
#   'evil',
#   'japanese',
#   'mob',
#   'villain',
#   'want',
#   'find',
#   'way',
#   'use',
#   'power',
#   'rule',
#   'worldinsert',
#   'evil',
#   'laugh',
#   'herethe',
#   'story',
#   'read',
#   'like',
#   'scooby',
#   'doo',
#   'mystery',
#   'point',
#   'kenji',
#   'secret',
#   'agent',
#   'team',
#   'agent',
#   'backing',
#   'entire',
#   'climax',
#   'story',
#   'filled',
#   'team',
#   'including',
#   'kat',
#   'uncle',
#   'family',
#   'member',
#   'fighting',
#   'score',
#   'assassin',
#   'ending',
#   'spoiler',
#   'alert',
#   'kat',
#   'kenji',
#   'using',
#   'power',
#   'kill',
#   'assassin',
#   'begs',
#   'question',
#   'easy',
#   'first',
#   'placethe',
#   'villain',
#   'described',
#   'physical',
#   'appearance',
#   'throughout',
#   'book',
#   'end',
#   'named',
#   'would',
#   'known',
#   'anyway',
#   'since',
#   'book',
#   'go',
#   'detail',
#   'lot',
#   'description',
#   'regarding',
#   'kind',
#   'car',
#   'everyone',
#   'driving',
#   'kind',
#   'watch',
#   'earring',
#   'shoe',
#   'kenji',
#   'crew',
#   'wearing',
#   'unnecessary',
#   'story',
#   'based',
#   'atlanta',
#   'georgia',
#   'mountain',
#   'seemed',
#   'odd',
#   'japanese',
#   'ninja',
#   'fight',
#   'also',
#   'hero',
#   'described',
#   'traditional',
#   'japanese',
#   'samurai',
#   'several',
#   'time',
#   'said',
#   'slang',
#   'term',
#   'seemed',
#   'character',
#   'author',
#   'credit',
#   'kat',
#   'question',
#   'still',
#   'place',
#   'character',
#   'inconsistancies',
#   'could',
#   'name',
#   'already',
#   'rather',
#   'wordy',
#   'think',
#   'get',
#   'pointthere',
#   'obvious',
#   'secondary',
#   'romance',
#   'thrown',
#   'set',
#   'sequel',
#   'let',
#   'hope',
#   'author',
#   'time',
#   'hone',
#   'craft',
#   'second',
#   'story',
#   'put',
#   'together'],
#  ['really', 'consider', 'bdsm', 'book', 'romantic', 'book', 'really', 'great'],
#  ['strange',
#   'make',
#   'weird',
#   'mr',
#   'baldacci',
#   'grotesque',
#   'imagination',
#   'oh',
#   'well',
#   'free',
#   'got',
#   'money',
#   'worth'],
#  ['idea',
#   'story',
#   'interesting',
#   'disliked',
#   'writer',
#   'style',
#   'storyline',
#   'confusing',
#   'follow',
#   'character',
#   'seemed',
#   'similar',
#   'description',
#   'seemed',
#   'stilted',
#   'dry',
#   'also',
#   'annoying',
#   'author',
#   'one',
#   'character',
#   'repeatedly',
#   'pondering',
#   'relationship',
#   'two',
#   'colleages',
#   'never',
#   'seemed',
#   'come',
#   'conclusion',
#   'everytime',
#   'came',
#   'storyline',
#   'thinking',
#   'didnt',
#   'already',
#   'go',
#   'usually',
#   'read',
#   'great',
#   'story',
#   'become',
#   'immersed',
#   'like',
#   'watching',
#   'movie',
#   'book',
#   'struggle',
#   'get',
#   'sorry',
#   'bad',
#   'review',
#   'didnt',
#   'enjoy'],
#  ['character',
#   'over-the-top',
#   'stereotype',
#   'clueless',
#   'dork',
#   'nasty',
#   'young',
#   'woman',
#   'way',
#   'world',
#   'work',
#   'isnt',
#   'clear',
#   '-',
#   'story',
#   'short',
#   'dont',
#   'want',
#   'spoil',
#   'anything',
#   'really',
#   'defies',
#   'belief',
#   'company',
#   'would',
#   'resource',
#   'like',
#   'use',
#   'limited',
#   'way',
#   'isnt',
#   'even',
#   'something',
#   'youd',
#   'need',
#   'real',
#   'life',
#   'low-level',
#   'employee',
#   'would',
#   'know',
#   'ending',
#   'like',
#   'unsatisfying',
#   'joke',
#   'felt',
#   'like',
#   'wasted',
#   'minute',
#   'took',
#   'read'],
#  ['hated',
#   'book',
#   'could',
#   'finish',
#   'itfull',
#   'beating',
#   'horrible',
#   'punishment',
#   'happy',
#   'endingi',
#   'agree',
#   'reviewer',
#   'buyer',
#   'beware'],
#  ['must',
#   'say',
#   'title',
#   'slightly',
#   'misleading',
#   'way',
#   'becomes',
#   'well-explained',
#   'didnt',
#   'mind',
#   'allctw',
#   'fast',
#   'paced',
#   'carry',
#   'rachel',
#   'myers',
#   'work',
#   'settling',
#   'homeplace',
#   'dealing',
#   'job',
#   'administrator',
#   'retirement',
#   'center',
#   'getting',
#   'beloved',
#   'garden',
#   'underway',
#   'furthering',
#   'relationship',
#   'detective',
#   'robert',
#   'barnetti',
#   'really',
#   'love',
#   'description',
#   'physical',
#   'mountain',
#   'wood',
#   'landscape',
#   'feel',
#   'like',
#   'im',
#   'actually',
#   'character',
#   'good',
#   'bad',
#   'truly',
#   'human',
#   'super-heroes',
#   'super-villains',
#   'giving',
#   'murderer',
#   'name',
#   'made',
#   'seem',
#   'even',
#   'ominousas',
#   'usual',
#   'm',
#   'jackson',
#   'book',
#   'well-formatted',
#   'meticulously',
#   'edited'],
#  ['thought',
#   'book',
#   'would',
#   'help',
#   'improve',
#   'digital',
#   'skill',
#   'case',
#   'author',
#   'give',
#   'good',
#   'piece',
#   'informationbut'],
#  ['real',
#   'fan',
#   'sci-fi',
#   'frank',
#   'herbert',
#   'book',
#   'dune',
#   'one',
#   'great',
#   'classic',
#   'sci-fi',
#   'story',
#   'standard',
#   'frankly',
#   'like',
#   'paid',
#   'write',
#   'story',
#   'many',
#   'word',
#   'magazine',
#   'suddenly',
#   'realized',
#   'needed',
#   'finish',
#   'story',
#   'quickly',
#   'abruptly',
#   'endsthe',
#   'story',
#   'start',
#   'well',
#   'like',
#   'one',
#   'andre',
#   'nortons',
#   'space',
#   'interplanetary',
#   'exploration',
#   'team',
#   'making',
#   'first',
#   'contact',
#   'new',
#   'race',
#   'man',
#   'assigned',
#   'task',
#   'making',
#   'first',
#   'contact',
#   'know',
#   'new',
#   'race',
#   'can',
#   'not',
#   'trusted',
#   'know',
#   'captured',
#   'space',
#   'ship',
#   'suddenly',
#   'within',
#   'question',
#   'solves',
#   'puzzle',
#   'ship',
#   'turn',
#   'table',
#   'captor',
#   'story',
#   'end',
#   'quickly',
#   'make',
#   'wonder',
#   'wasted',
#   'time',
#   'reading',
#   '30',
#   'minute',
#   'reading',
#   'time',
#   'interest',
#   'book',
#   'go',
#   'ahead',
#   'enjoy',
#   'glad',
#   'didnt',
#   'pay',
#   'book'],
#  ['complexity',
#   'detail',
#   'story',
#   'amazes',
#   'especially',
#   'since',
#   'recently',
#   'published',
#   'story',
#   'hard',
#   'put'],
#  ['enjoy',
#   'book',
#   'definitely',
#   'sex',
#   'marathon',
#   'lena',
#   'luke',
#   'plot',
#   'could',
#   'kill',
#   'luke',
#   'try',
#   'save',
#   'people',
#   'writing',
#   'decent',
#   'like',
#   'character',
#   'luke',
#   'story',
#   'could',
#   'still',
#   'use',
#   'work',
#   'edition',
#   'could',
#   'still',
#   'use',
#   'editing',
#   'author',
#   'annoying',
#   'tendency',
#   'constantly',
#   'identifying',
#   'character',
#   'rather',
#   'switching',
#   'first',
#   'time',
#   'pulled',
#   'story',
#   'occasionally',
#   'major',
#   'issue',
#   'sex',
#   'tend',
#   'go',
#   'definitely',
#   'hot',
#   'moment',
#   'whole',
#   'scene',
#   'luke',
#   'monster',
#   'form',
#   'pretty',
#   'ridiculous',
#   'didnt',
#   'ruin',
#   'entire',
#   'book',
#   'got',
#   'little',
#   'confused',
#   'character',
#   'thrown',
#   'story',
#   'obviously',
#   'set',
#   'future',
#   'book',
#   'series',
#   '5',
#   'best',
#   'friend',
#   'including',
#   'lena',
#   'plus',
#   'luke',
#   '2',
#   'buddy',
#   'couldnt',
#   'really',
#   'keep',
#   'who',
#   'got',
#   'together',
#   'there',
#   'small',
#   'bit',
#   'action',
#   'story',
#   'luke',
#   'quest',
#   'make',
#   'movie',
#   'doesnt',
#   'actually',
#   'happen',
#   'story',
#   'im',
#   'sure',
#   'going',
#   'prolonged',
#   'course',
#   'series',
#   'warned',
#   'definitely',
#   'story',
#   'lena',
#   'luke',
#   'relationship',
#   'sex',
#   'life',
#   'really',
#   'anything',
#   'else',
#   'feel',
#   'author',
#   'missed',
#   'opportunity',
#   'expand',
#   'life',
#   'world',
#   'monster',
#   'overall',
#   'liked',
#   'definitely',
#   'good',
#   'looking',
#   'little',
#   'steamy',
#   'bit',
#   'escapist',
#   'fluff'],
#  ['begin',
#   'guess',
#   'ill',
#   'jump',
#   'right',
#   'say',
#   'probably',
#   'shouldnt',
#   'spent',
#   'time',
#   'reading',
#   'spending',
#   'working',
#   '2',
#   'essay',
#   'due',
#   '2',
#   'day',
#   'working',
#   'essay',
#   'grad',
#   'school',
#   'would',
#   'fun',
#   'reading',
#   'book',
#   'sadlythe',
#   'character',
#   'really',
#   'liked',
#   'madame',
#   'medusala',
#   'mom',
#   'hero',
#   'heroine',
#   'little',
#   'bring',
#   'story',
#   'sad',
#   'really',
#   'lot',
#   'potential',
#   'story',
#   'felt',
#   'contrived',
#   'dialogue',
#   'forced',
#   'unfunny',
#   'could',
#   'tell',
#   'author',
#   'going',
#   'breezy',
#   'funny',
#   'romantic',
#   'banter',
#   'didnt',
#   'work',
#   'neither',
#   'sex',
#   'scene',
#   'im',
#   'far',
#   'prude',
#   'wasnt',
#   'biting',
#   'made',
#   'like',
#   'referring',
#   'warning',
#   'product',
#   'description',
#   'little',
#   'build',
#   'happened',
#   'day',
#   'hero',
#   'heroine',
#   'met',
#   'romanticsexual',
#   'tension',
#   'prefer',
#   'book',
#   'simply',
#   'lacking',
#   'hero',
#   'heroine',
#   'easily',
#   'manipulated',
#   'outside',
#   'force',
#   'father',
#   'maxi',
#   'dont',
#   'know',
#   'much',
#   'version',
#   'book',
#   'changed',
#   'original',
#   'book',
#   'short',
#   'story',
#   'novella',
#   'instead',
#   'noveli',
#   'got',
#   'book',
#   'free',
#   'amazon',
#   'dont',
#   'buyer',
#   'remorse',
#   'didnt',
#   'hate',
#   'book',
#   'would',
#   'recommend',
#   'reservation',
#   'also',
#   'sillier',
#   'mood',
#   'read',
#   'might',
#   'worked',
#   'giving',
#   'benefit',
#   'doubtsensuality',
#   'sex',
#   'scenesrating',
#   '2',
#   'star'],
#  ['love',
#   'book',
#   'several',
#   'story',
#   'heard',
#   'child',
#   'never',
#   'heard',
#   'read',
#   'wonderful',
#   'book'],
#  ['book',
#   'wizard',
#   'high',
#   'class',
#   'girl',
#   'start',
#   'find',
#   'world',
#   'realizes',
#   'like',
#   'character',
#   'great',
#   'story',
#   'moved',
#   'good',
#   'pace'],
#  ['despite',
#   'corny',
#   'feel',
#   'game',
#   'gay',
#   'chicken',
#   'book',
#   'definitely',
#   'worth',
#   'read',
#   're-read',
#   'maybe',
#   'even',
#   'third',
#   'thats',
#   'hot',
#   'two',
#   'guy',
#   'together',
#   'also',
#   'attraction',
#   'didnt',
#   'feel',
#   'forced',
#   'thought',
#   'flowed',
#   'perfectly',
#   'fakkit',
#   'ill',
#   'probably',
#   'read',
#   'fourth',
#   'time'],
#  ['like',
#   'idea',
#   '--',
#   'man',
#   'drag',
#   'straight',
#   'guy',
#   'realizes',
#   'he',
#   'actually',
#   'gay',
#   'convert',
#   'someone',
#   'else',
#   'actually',
#   'read',
#   'anything',
#   'concept',
#   'plot',
#   'faintly',
#   'ridiculous',
#   'however',
#   'maybe',
#   'always',
#   'going',
#   'waiting',
#   'cop',
#   'bust',
#   'house-wife',
#   'organized',
#   'pot',
#   'ring',
#   'bit',
#   'much',
#   'hey',
#   'read',
#   'romance',
#   'would',
#   'let',
#   'go',
#   'character',
#   'good',
#   'enoughbut',
#   'actually',
#   'found',
#   'faintly',
#   'unpleasant',
#   'hero',
#   'knew',
#   'little',
#   'guy',
#   'shacking',
#   'love',
#   'interest',
#   'subdued',
#   'wasnt',
#   'sure',
#   'felt',
#   'author',
#   'attempted',
#   'fix',
#   'end',
#   'character',
#   'say',
#   'something',
#   'like',
#   'didnt',
#   'say',
#   'much',
#   'action',
#   'spoke',
#   'oh',
#   'brothersex',
#   'scene',
#   'bad',
#   'grey',
#   'awakening',
#   'lem',
#   'me',
#   'tell'],
#  ...]

# %% [markdown]
# 1. vector_size=100: Dimension of word embeddings.
# 2. window=5: Context window size.
# 3. min_count=2: Ignores words that appear less than twice.
# 4. sg=1: Skip-gram model (use sg=0 for CBOW).

# %%
# Train Word2Vec on training tokens
word2vec_model = Word2Vec(sentences=X_train_tokens, vector_size=100, window=5, min_count=2, workers=4, sg=1)

# %%
#to get all the Vocabulary
word2vec_model.wv.index_to_key
# Out:
# ['book',
#  'story',
#  'read',
#  'one',
#  'character',
#  'like',
#  'good',
#  'would',
#  'really',
#  'love',
#  'time',
#  'get',
#  'author',
#  'reading',
#  'series',
#  'much',
#  'first',
#  'well',
#  'even',
#  'didnt',
#  'short',
#  'know',
#  'way',
#  'could',
#  'great',
#  'make',
#  'little',
#  '-',
#  'sex',
#  'dont',
#  'thing',
#  'want',
#  'two',
#  'think',
#  'find',
#  'plot',
#  'also',
#  'romance',
#  'im',
#  'life',
#  'end',
#  'go',
#  'see',
#  'enjoyed',
#  'never',
#  'scene',
#  'take',
#  'woman',
#  'kindle',
#  'written',
#  'many',
#  'lot',
#  'say',
#  'work',
#  'bit',
#  'thought',
#  'going',
#  'give',
#  'found',
#  'year',
#  'writing',
#  'interesting',
#  'liked',
#  'got',
#  'loved',
#  'novel',
#  'feel',
#  'another',
#  'still',
#  'better',
#  'back',
#  'though',
#  'man',
#  'enough',
#  'come',
#  'people',
#  'hot',
#  'reader',
#  'made',
#  'something',
#  'review',
#  'cant',
#  'part',
#  'free',
#  'page',
#  'need',
#  'star',
#  'friend',
#  'bad',
#  'keep',
#  'new',
#  'world',
#  'wasnt',
#  'doesnt',
#  'relationship',
#  'enjoy',
#  'felt',
#  'recommend',
#  'together',
#  'next',
#  'start',
#  'best',
#  'guy',
#  'put',
#  'word',
#  'looking',
#  'main',
#  'however',
#  'since',
#  'fun',
#  'real',
#  '--',
#  'long',
#  'day',
#  'hard',
#  'line',
#  'ive',
#  'ending',
#  'couldnt',
#  'point',
#  'sure',
#  'different',
#  'family',
#  'without',
#  'right',
#  'wanted',
#  'always',
#  'nothing',
#  'every',
#  'anything',
#  'hero',
#  'definitely',
#  'heroine',
#  'actually',
#  'action',
#  'look',
#  'ever',
#  'men',
#  'shes',
#  'three',
#  'worth',
#  'pretty',
#  'old',
#  'problem',
#  'help',
#  'let',
#  'seemed',
#  'whole',
#  'quite',
#  'feeling',
#  'fact',
#  'he',
#  'around',
#  'try',
#  'sexy',
#  'might',
#  'tell',
#  'idea',
#  'second',
#  'place',
#  'left',
#  'nice',
#  'isnt',
#  'away',
#  'getting',
#  'someone',
#  'kind',
#  'thats',
#  'brother',
#  'may',
#  'mystery',
#  'started',
#  'turn',
#  'vampire',
#  'chapter',
#  'almost',
#  'done',
#  'girl',
#  'tale',
#  'far',
#  'couple',
#  '2',
#  'set',
#  'seems',
#  'last',
#  'issue',
#  'yet',
#  'kept',
#  'reason',
#  'maybe',
#  'wish',
#  'past',
#  'trying',
#  'quick',
#  'said',
#  'novella',
#  'fantasy',
#  'finish',
#  'everything',
#  'beginning',
#  'mind',
#  'others',
#  'description',
#  'writer',
#  'must',
#  'believe',
#  'full',
#  'mate',
#  'hope',
#  'strong',
#  'meet',
#  'fan',
#  'job',
#  'father',
#  'development',
#  'least',
#  'night',
#  'able',
#  'money',
#  'sweet',
#  'wont',
#  'care',
#  'forward',
#  'especially',
#  'anyone',
#  'erotic',
#  'big',
#  'mean',
#  'home',
#  'human',
#  'although',
#  'child',
#  'easy',
#  'understand',
#  'used',
#  'show',
#  'buy',
#  'happy',
#  'went',
#  'u',
#  '3',
#  'id',
#  'young',
#  'disappointed',
#  'took',
#  'there',
#  'detail',
#  'gave',
#  'probably',
#  'storyline',
#  'favorite',
#  'person',
#  'sense',
#  'rather',
#  'wait',
#  'style',
#  'seem',
#  'wonderful',
#  'case',
#  'sexual',
#  'fast',
#  'interest',
#  'write',
#  'instead',
#  'use',
#  'rest',
#  'high',
#  'heart',
#  'given',
#  'told',
#  'along',
#  'price',
#  'le',
#  'wrong',
#  'true',
#  'female',
#  'several',
#  'type',
#  'came',
#  'change',
#  'longer',
#  'lost',
#  'error',
#  'else',
#  'male',
#  'course',
#  'twist',
#  'either',
#  'alpha',
#  'knew',
#  'developed',
#  '5',
#  'completely',
#  'cover',
#  'light',
#  'stop',
#  'perfect',
#  'm',
#  'ok',
#  'overall',
#  'finally',
#  'fall',
#  'side',
#  'quickly',
#  'glad',
#  'later',
#  'future',
#  'enjoyable',
#  'making',
#  'husband',
#  'half',
#  'waste',
#  'happened',
#  'youre',
#  'name',
#  'happens',
#  'happen',
#  '4',
#  'believable',
#  'attention',
#  'lead',
#  'order',
#  'fiction',
#  'steamy',
#  'situation',
#  'bought',
#  'mother',
#  'wolf',
#  'become',
#  'everyone',
#  'boring',
#  'finished',
#  'ill',
#  'wouldnt',
#  'needed',
#  'eye',
#  'premise',
#  'already',
#  'interested',
#  'highly',
#  'sister',
#  'entire',
#  'chance',
#  'lover',
#  'amazon',
#  'okay',
#  '1',
#  'call',
#  'moment',
#  'truly',
#  'school',
#  'wife',
#  'werewolf',
#  'ended',
#  'sometimes',
#  'boy',
#  'thinking',
#  'genre',
#  'version',
#  'town',
#  'move',
#  'leave',
#  'totally',
#  'dark',
#  'yes',
#  'dialogue',
#  'guess',
#  'h',
#  'hand',
#  'follow',
#  'sort',
#  'live',
#  'usually',
#  'lack',
#  'paranormal',
#  'head',
#  'experience',
#  'funny',
#  'entertaining',
#  'title',
#  'romantic',
#  'language',
#  'sorry',
#  'war',
#  'figure',
#  'reviewer',
#  'save',
#  'editing',
#  'pick',
#  'length',
#  'turned',
#  'house',
#  'deal',
#  'wanting',
#  'run',
#  'secret',
#  'alone',
#  'stand',
#  'age',
#  'coming',
#  'expected',
#  'simply',
#  'giving',
#  'adult',
#  'absolutely',
#  'death',
#  'unfortunately',
#  'often',
#  'expect',
#  'month',
#  'depth',
#  'begin',
#  'add',
#  'matter',
#  'potential',
#  'dragon',
#  'throughout',
#  'soon',
#  'collection',
#  'erotica',
#  'dream',
#  'spent',
#  'ago',
#  'pack',
#  'certainly',
#  'hour',
#  'oh',
#  'poor',
#  'theyre',
#  'decided',
#  'small',
#  'history',
#  'emotion',
#  'third',
#  'complete',
#  'easily',
#  'four',
#  'shifter',
#  'face',
#  'living',
#  'learn',
#  'hate',
#  'difficult',
#  'supposed',
#  'excellent',
#  'adventure',
#  'top',
#  'across',
#  'gay',
#  'setting',
#  'stay',
#  'opinion',
#  'humor',
#  'slow',
#  'continue',
#  'list',
#  'information',
#  'hold',
#  'sentence',
#  'missing',
#  'realize',
#  'killer',
#  'called',
#  'event',
#  'movie',
#  'beyond',
#  'perhaps',
#  'kill',
#  'tried',
#  'week',
#  'finding',
#  'attraction',
#  'talk',
#  'god',
#  'mr',
#  'minute',
#  'suspense',
#  'fight',
#  'extremely',
#  'play',
#  'hell',
#  'background',
#  'plan',
#  'bed',
#  'pay',
#  'predictable',
#  'question',
#  'surprised',
#  'break',
#  'seen',
#  'rating',
#  'involved',
#  'group',
#  'power',
#  'emotional',
#  'beautiful',
#  'daughter',
#  'son',
#  'amazing',
#  'kid',
#  'murder',
#  'marriage',
#  'level',
#  'remember',
#  'form',
#  'magic',
#  'force',
#  'within',
#  'behind',
#  'known',
#  'cute',
#  'connection',
#  'soul',
#  'youll',
#  'taking',
#  'married',
#  'concept',
#  'based',
#  'trouble',
#  'met',
#  'became',
#  'choice',
#  'middle',
#  'five',
#  'seeing',
#  'saying',
#  'content',
#  'waiting',
#  'spoiler',
#  'business',
#  'surprise',
#  'downloaded',
#  'hunter',
#  'heat',
#  'chemistry',
#  'working',
#  'science',
#  'example',
#  'etc',
#  'taken',
#  'due',
#  'clear',
#  'mistake',
#  'desire',
#  'loving',
#  'number',
#  'fell',
#  'aspect',
#  'exactly',
#  'immediately',
#  'body',
#  'mark',
#  'share',
#  'drawn',
#  'stuff',
#  'james',
#  'saw',
#  'admit',
#  'seriously',
#  'room',
#  'brought',
#  'important',
#  'view',
#  'huge',
#  'bring',
#  'close',
#  'return',
#  'fine',
#  'early',
#  'becomes',
#  'fit',
#  'ability',
#  'christmas',
#  'hoping',
#  'fairy',
#  'lady',
#  'decides',
#  'realistic',
#  'weak',
#  'mention',
#  'somewhat',
#  'simple',
#  'editor',
#  'personal',
#  'not',
#  'leaf',
#  'wonder',
#  'forced',
#  'mostly',
#  'serious',
#  'annoying',
#  'alex',
#  'passion',
#  'using',
#  'can',
#  'despite',
#  'havent',
#  'fairly',
#  'original',
#  'unique',
#  'sequel',
#  'expecting',
#  'evil',
#  'piece',
#  'bother',
#  'special',
#  'hurt',
#  'spend',
#  'ready',
#  'strange',
#  'picture',
#  'check',
#  'paid',
#  'note',
#  'serial',
#  'open',
#  'telling',
#  'conflict',
#  'partner',
#  'willing',
#  'dead',
#  'flow',
#  'classic',
#  'demon',
#  'space',
#  'fear',
#  'black',
#  'element',
#  'none',
#  'caught',
#  'trust',
#  'described',
#  'except',
#  'building',
#  'graphic',
#  'earth',
#  'quality',
#  'previous',
#  'taste',
#  'please',
#  'certain',
#  'horror',
#  'basically',
#  'exciting',
#  'older',
#  'present',
#  'upon',
#  'worked',
#  'stupid',
#  'download',
#  'arent',
#  'tension',
#  'police',
#  'angel',
#  'control',
#  'act',
#  'major',
#  'bdsm',
#  'date',
#  'paper',
#  'plus',
#  'mentioned',
#  'offer',
#  'neither',
#  'thoroughly',
#  'build',
#  'picked',
#  'grammar',
#  'buying',
#  'christian',
#  'historical',
#  'reviewed',
#  'rushed',
#  'typical',
#  'available',
#  'lose',
#  'menage',
#  'parent',
#  'filled',
#  'blog',
#  'zombie',
#  'unless',
#  'baby',
#  'crazy',
#  'intriguing',
#  'honest',
#  'added',
#  'knowing',
#  'gone',
#  'car',
#  'kelly',
#  'poorly',
#  'drama',
#  'agree',
#  'typo',
#  'boyfriend',
#  'single',
#  'normally',
#  'purchase',
#  'attempt',
#  'copy',
#  'super',
#  'paragraph',
#  'straight',
#  'wrote',
#  '10',
#  'alien',
#  'miss',
#  'decent',
#  'cat',
#  'held',
#  'writes',
#  'blood',
#  'knight',
#  'blake',
#  'sad',
#  'including',
#  'king',
#  'confusing',
#  'touch',
#  'meeting',
#  'sample',
#  'purchased',
#  'sound',
#  'amount',
#  'recommended',
#  'game',
#  'edition',
#  'wedding',
#  'lord',
#  'theme',
#  'struggle',
#  'hit',
#  'suddenly',
#  'whats',
#  'fantastic',
#  'personality',
#  'talking',
#  'whether',
#  'basic',
#  'promise',
#  'nature',
#  'determined',
#  'particularly',
#  'marry',
#  'master',
#  'accept',
#  'protagonist',
#  'possible',
#  'published',
#  'awesome',
#  'worst',
#  'thrown',
#  'pas',
#  'fully',
#  'develop',
#  'stopped',
#  'silly',
#  'horrible',
#  'werent',
#  'term',
#  'interaction',
#  'thriller',
#  'paced',
#  'joyfully',
#  'reality',
#  'escape',
#  'leaving',
#  'period',
#  'thank',
#  'animal',
#  'jump',
#  'cause',
#  'prequel',
#  'imagine',
#  'truth',
#  'fighting',
#  'ridiculous',
#  'jake',
#  'flat',
#  'odd',
#  'otherwise',
#  'jack',
#  'trilogy',
#  'ghost',
#  'conversation',
#  'edge',
#  'moving',
#  'realized',
#  'john',
#  'article',
#  'encounter',
#  'deep',
#  'honestly',
#  'cut',
#  'actual',
#  'today',
#  'moved',
#  'belief',
#  'apparently',
#  'worse',
#  'confused',
#  'detective',
#  'pull',
#  'area',
#  'pace',
#  'kate',
#  'particular',
#  'familiar',
#  'american',
#  'subject',
#  'effort',
#  'modern',
#  'introduced',
#  'plenty',
#  'missed',
#  'consider',
#  'protect',
#  'voice',
#  'step',
#  'club',
#  'rich',
#  'focus',
#  'wow',
#  'english',
#  'state',
#  'max',
#  'news',
#  'killed',
#  'near',
#  '99',
#  'satisfying',
#  'keeping',
#  'difference',
#  'skip',
#  'hooked',
#  'unbelievable',
#  'running',
#  'bored',
#  'changed',
#  'falling',
#  'land',
#  'watching',
#  'ex',
#  'answer',
#  'nearly',
#  'explicit',
#  'killing',
#  'door',
#  'decide',
#  'speak',
#  'hadnt',
#  'ebook',
#  'crime',
#  'appreciate',
#  'fire',
#  'pleasure',
#  'created',
#  'draw',
#  'decision',
#  'apart',
#  'formatting',
#  'anyway',
#  'weird',
#  'purpose',
#  'conclusion',
#  'engaging',
#  'lie',
#  'late',
#  'jane',
#  'journey',
#  'violence',
#  'literally',
#  'happily',
#  'wondering',
#  'self',
#  'reference',
#  'cold',
#  'terrible',
#  'turning',
#  'looked',
#  'pain',
#  'us',
#  'outside',
#  'doubt',
#  'rape',
#  'society',
#  'explanation',
#  'obviously',
#  'normal',
#  'party',
#  'grab',
#  'throw',
#  'battle',
#  'west',
#  'laugh',
#  'ask',
#  'city',
#  'win',
#  'warning',
#  'introduction',
#  'brings',
#  'role',
#  'realizes',
#  'ship',
#  'similar',
#  'putting',
#  'final',
#  'company',
#  'race',
#  'beauty',
#  'happening',
#  'college',
#  'mysterious',
#  'received',
#  'sci-fi',
#  'enjoying',
#  'research',
#  'section',
#  '6',
#  'create',
#  'intense',
#  'solid',
#  'younger',
#  'claim',
#  'included',
#  'barely',
#  'eventually',
#  'allow',
#  'cowboy',
#  'tired',
#  'bond',
#  'catch',
#  'lacking',
#  'team',
#  'letter',
#  'danger',
#  'installment',
#  'obvious',
#  'imagination',
#  'inside',
#  'meant',
#  'magical',
#  'wild',
#  'cole',
#  'slightly',
#  'large',
#  'afraid',
#  'forget',
#  'towards',
#  'likable',
#  'emma',
#  'attracted',
#  'cop',
#  'red',
#  'explained',
#  'lived',
#  'format',
#  'trip',
#  'mm',
#  'sight',
#  'incredibly',
#  'detailed',
#  'clearly',
#  'material',
#  'member',
#  'following',
#  'teenager',
#  'usual',
#  'cousin',
#  'product',
#  'walk',
#  'friendship',
#  'perspective',
#  'law',
#  'henry',
#  'powerful',
#  'awful',
#  'watch',
#  'constantly',
#  'witch',
#  'appears',
#  'various',
#  'military',
#  'current',
#  'michael',
#  'safe',
#  'print',
#  'rate',
#  'learning',
#  'disappointing',
#  'began',
#  'freebie',
#  'suggest',
#  'verne',
#  'disappointment',
#  'handsome',
#  'starting',
#  'lust',
#  'comment',
#  ...]

# %%
# word2vec_model.corpus_count
word2vec_model.corpus_total_words
# Out:
# 528255

# %%
word2vec_model.epochs
# Out:
# 5

# %%
def avg_word2vec(tokens, model, vector_size):
    """Compute the average Word2Vec for a list of tokens."""
    vectors = [model.wv[word] for word in tokens if word in model.wv.index_to_key]
    if len(vectors) > 0:
        return np.mean(vectors, axis=0)
    else:
        return np.zeros(vector_size)

# %%
# Convert reviews to average Word2Vec vectors
X_train_avg = np.array([avg_word2vec(tokens, word2vec_model, 100) for tokens in X_train_tokens])
X_test_avg = np.array([avg_word2vec(tokens, word2vec_model, 100) for tokens in X_test_tokens])

# %%
X_train_avg.shape
# Out:
# (9600, 100)

# %%
y_train.shape
# Out:
# (9600,)

# %%
X_train_avg[0]
# Out:
# array([-6.85541704e-02,  1.33944884e-01,  1.18232341e-02,  7.59147853e-02,
#        -2.52504945e-02, -3.50893080e-01,  1.30040899e-01,  4.45157170e-01,
#        -1.57052010e-01, -2.46515930e-01,  4.36806343e-02, -2.64905483e-01,
#        -9.60062817e-02,  1.60317779e-01,  6.68976009e-02, -2.48591840e-01,
#         6.30708337e-02, -2.68512726e-01, -1.19125351e-01, -4.20164883e-01,
#         7.38725513e-02,  6.27173334e-02,  1.00196011e-01, -3.87590267e-02,
#        -6.05193600e-02,  1.64753437e-01, -1.32651001e-01, -7.53857568e-02,
#        -9.64473188e-02,  8.28819536e-03,  1.90445215e-01,  3.61470804e-02,
#         8.14405456e-02, -2.12549433e-01, -1.11483715e-01,  2.33321130e-01,
#         8.25535432e-02, -1.79540232e-01, -4.65773270e-02, -3.21557015e-01,
#        -3.53576802e-02, -2.05681667e-01,  1.73125900e-02,  1.59416333e-01,
#         3.59129429e-01, -5.17748110e-02, -1.61928728e-01,  2.00907048e-02,
#         1.40834510e-01,  1.21113181e-01,  5.86525276e-02, -1.83487639e-01,
#        -1.02905214e-01, -8.56664479e-02, -7.29661211e-02,  1.34594381e-01,
#         1.77524954e-01,  2.81445595e-04, -1.33614585e-01,  1.38459131e-01,
#         6.09515272e-02, -5.24298884e-02,  8.94629583e-02, -3.32998149e-02,
#        -1.61057293e-01,  2.36506477e-01,  1.50115669e-01,  2.64197618e-01,
#        -3.08584541e-01,  3.30855370e-01, -1.17432833e-01,  7.88118541e-02,
#         1.59228474e-01, -5.02125174e-03,  2.27130756e-01,  2.88950633e-02,
#         1.47238433e-01,  9.52359885e-02, -1.72571018e-01, -3.89970094e-02,
#        -3.20685416e-01,  6.11662045e-02, -1.98381633e-01,  3.31892103e-01,
#        -7.27219647e-03, -1.03050368e-02,  2.57462829e-01,  1.07591562e-01,
#         3.22990060e-01,  1.07994474e-01,  3.75282973e-01,  1.04846053e-01,
#         5.78281842e-02,  5.14548793e-02,  2.11263418e-01,  1.64910436e-01,
#         1.96891829e-01, -1.94676757e-01,  2.73959134e-02,  5.40599450e-02],
#       dtype=float32)

# %%
from sklearn.naive_bayes import GaussianNB
nb_model = GaussianNB().fit(X_train_avg,y_train)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
y_pred = nb_model.predict(X_test_avg)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7479166666666667

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 593,  184],
#        [ 421, 1202]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.76      0.66       777
#            1       0.87      0.74      0.80      1623
#
#     accuracy                           0.75      2400
#    macro avg       0.73      0.75      0.73      2400
# weighted avg       0.78      0.75      0.75      2400

# %%
from sklearn.linear_model import LogisticRegression
# Initialize Logistic Regression model
log_reg = LogisticRegression(max_iter=1000)

# Train the model
log_reg.fit(X_train_avg, y_train)

# Predict on the test set
y_pred_LR = log_reg.predict(X_test_avg)

# Evaluate the model
print(f"Accuracy: {accuracy_score(y_test, y_pred_LR)}")
print(f"Confusion Matrix:\n{confusion_matrix(y_test, y_pred_LR)}")
print(f"Classification Report:\n{classification_report(y_test, y_pred_LR)}")
# Out:
# Accuracy: 0.81125
# Confusion Matrix:
# [[ 475  302]
#  [ 151 1472]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.61      0.68       777
#            1       0.83      0.91      0.87      1623
#
#     accuracy                           0.81      2400
#    macro avg       0.79      0.76      0.77      2400
# weighted avg       0.81      0.81      0.81      2400

# %%
from sklearn.model_selection import GridSearchCV

# Define parameter grid
param_grid = {'C': [0.01, 0.1, 1, 10, 100]}

# Perform Grid Search
grid_search = GridSearchCV(estimator=LogisticRegression(max_iter=1000), param_grid=param_grid, cv=5, scoring='accuracy', verbose=1)
grid_search.fit(X_train_avg, y_train)

# Best model evaluation
best_model = grid_search.best_estimator_
y_pred_GS = best_model.predict(X_test_avg)

print(f"Best Parameters: {grid_search.best_params_}")
print(f"Accuracy: {accuracy_score(y_test, y_pred_GS)}")
print(f"Confusion Matrix:\n{confusion_matrix(y_test, y_pred_GS)}")
print(f"Classification Report:\n{classification_report(y_test, y_pred_GS)}")
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Best Parameters: {'C': 10}
# Accuracy: 0.8120833333333334
# Confusion Matrix:
# [[ 482  295]
#  [ 156 1467]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.62      0.68       777
#            1       0.83      0.90      0.87      1623
#
#     accuracy                           0.81      2400
#    macro avg       0.79      0.76      0.77      2400
# weighted avg       0.81      0.81      0.81      2400
